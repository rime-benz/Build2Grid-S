# %%
import pandas as pd
from docx import Document

# %%
network_df = pd.read_excel("reseau_en_arbre.xlsx")


broken_network_df = network_df[network_df["infra_type"] == "a_remplacer"]


set_id_batiments = set(network_df["id_batiment"].values)
set_id_broken_batiments = set(broken_network_df["id_batiment"].values)

list_id_batiment = []
state_batiment = []

for id_batiment in set_id_batiments:
    list_id_batiment.append(id_batiment)
    if id_batiment in set_id_broken_batiments:
        state_batiment.append("à_reparer")  # bâtiment à réparer
    else:
        state_batiment.append("intact")     # bâtiment intact


state_df = pd.DataFrame({
    "id_bat": list_id_batiment,
    "state_batiment": state_batiment
})

header_row = pd.DataFrame([state_df.columns], columns=state_df.columns)

df_final = pd.concat([header_row, state_df], ignore_index=True)

df_final.to_excel("etat_batiment.xlsx", index=False, header=False)
print("Fichier 'etat_batiment.xlsx' généré avec succès.")
# Out:
# Fichier 'etat_batiment.xlsx' généré avec succès.

# %% [markdown]
# 1- Il faut recupérer pour un seul infra les differents batiment qu'il permet de raccorder
# 2- la metrique d'évaluation de la priorité pour le moment est longueur_d'infra/nbr_maison(nbr_prise) métrique de difficulté pour reconstruire un seul infra.
# 3- pour chaque batiment on a une liste des infras du départ jusqu'au arrivée (de l'origine de l'infra jusqu'au dernier batiment), c'est déjà ordonnée dans le fichier xlsx
# 4- résultat : 4 phases de reconstruction (4 degrées de priorité pour chaque batiment)
# 5- il faut résonner en fonction d'un chemin d'infra (et pas par 1 infra parce que ça sert à rien de reconstruire une infra dans la 1ere phase par exemple sans reconstituer l'electricité dans le batiment). du coup la métrique devient : somme(longueur_d'infra/nbr_maison_dependant_de_cette_infra) pour chaque batiment. Exemple :
# id_batiment	nb_maisons	infra_id	infra_type	longueur
# E000001	4	P007111	infra_intacte	12.3144613356693
# E000001	4	P007983	infra_intacte	40.3209288665353
# E000001	4	P000308	infra_intacte	39.1407985664577
# E000001	4	P007819	infra_intacte	17.3904643240185
# 6- on va calculer la difficulté de chaque infra , pour faire la somme facilement par batiment.
# 7- quand on répare un infra il faut mettre à jour la métrique.
# 8- metrique final cout*duree/nbr_prise par batiment = somme de cout*duree/nbr_prise par infra
# 9- on va tout simplement dans le tableau excel ajouter une colonne cout en euros et une colonne durée en temps et une colonne type_reparation(aerien/semi-aérien/fourreau)
# 10- pour la mise a jour c'est simple , a chaque fois qu'une infra est remplacé on la fait sortir de la liste des broken_infra et on recalcule la somme de cout*duree/nbr_prise par infra .

# %%
class Infra:

    def __init__(self,infra_id,length,infra_type,nb_house):
        self.infra_id = infra_id
        self.length = length
        self.infra_type = infra_type
        self.nb_house = nb_house

    def __repr__(self):
        return f"Infrastructure {self.infra_id} | Type: {self.infra_type} | Length: {self.length}m | Houses: {self.nb_house}"

    def repair_infra(self):
        pass

    def get_infra_difficulty(self) :
        return self.length/self.nb_house

# %%
class Building:

    def __init__(self,id_building,list_infra):
        self.id_building = id_building
        self.list_infra = []

    def add_infra(self, infra):
        self.list_infra.append(infra)

    def get_building_difficulty(self) :
        s = 0
        for infra in self.list_infra : s+=infra.get_infra_difficulty()
        return s

    def add_infra(self, infra):
        self.list_infra.append(infra)
        
    def __repr__(self):
        return f"Building {self.id_building} | {self.list_infra}"

# %%
#1er script : calcul de la 1ere métrique :

network_df = pd.read_excel("reseau_en_arbre.xlsx")
broken_network_df = network_df[network_df["infra_type"] == "a_remplacer"]


broken_infra = []
buildings_without_electricity = []
infra_difficulties = {}
buildings = {}
building_difficulties = {}

for _,infra in broken_network_df.iterrows():
    infrastructure = Infra(infra_id=infra["infra_id"], length=infra["longueur"], infra_type=infra["infra_type"], nb_house=infra["nb_maisons"])
    broken_infra.append(infrastructure)

print(broken_infra)

for infra, building_id in zip(broken_infra, broken_network_df["id_batiment"]):
    if building_id not in buildings:
        buildings[building_id] = Building(building_id, [])
    buildings[building_id].list_infra.append(infra)

buildings_without_electricity = list(buildings.values())

print(buildings_without_electricity)

for infra in broken_infra :
    infra_difficulties[infra.infra_id] = infra.get_infra_difficulty()

print(infra_difficulties)

for building in buildings_without_electricity :
    building_difficulties[building.id_building] = building.get_building_difficulty()


final_result = dict(sorted(building_difficulties.items(), key=lambda item: item[1]))
print(final_result)
# Out:
# [Infrastructure P007113 | Type: a_remplacer | Length: 12.1935087083631m | Houses: 1, Infrastructure P007984 | Type: a_remplacer | Length: 30.0575979492587m | Houses: 1, Infrastructure P007823 | Type: a_remplacer | Length: 12.290282829583m | Houses: 1, Infrastructure P006193 | Type: a_remplacer | Length: 12.1863879405322m | Houses: 1, Infrastructure P002851 | Type: a_remplacer | Length: 10.8032015604234m | Houses: 1, Infrastructure P007624 | Type: a_remplacer | Length: 4.10990474598487m | Houses: 1, Infrastructure P005500 | Type: a_remplacer | Length: 13.1420349052071m | Houses: 1, Infrastructure P007990 | Type: a_remplacer | Length: 18.7028610321555m | Houses: 1, Infrastructure P007447 | Type: a_remplacer | Length: 2.84535154473363m | Houses: 1, Infrastructure P005531 | Type: a_remplacer | Length: 14.8493095953268m | Houses: 1, Infrastructure P007639 | Type: a_remplacer | Length: 6.13280316452202m | Houses: 1, Infrastructure P005500 | Type: a_remplacer | Length: 13.1420349052071m | Houses: 1, Infrastructure P007990 | Type: a_remplacer | Length: 18.7028610321555m | Houses: 1, Infrastructure P001391 | Type: a_remplacer | Length: 7.63593644945982m | Houses: 1, Infrastructure P007752 | Type: a_remplacer | Length: 3.12835142463862m | Houses: 1, Infrastructure P005500 | Type: a_remplacer | Length: 13.1420349052071m | Houses: 1, Infrastructure P007990 | Type: a_remplacer | Length: 18.7028610321555m | Houses: 1, Infrastructure P001391 | Type: a_remplacer | Length: 7.63593644945982m | Houses: 1, Infrastructure P007689 | Type: a_remplacer | Length: 5.1037127857757m | Houses: 1, Infrastructure P005500 | Type: a_remplacer | Length: 13.1420349052071m | Houses: 1, Infrastructure P007991 | Type: a_remplacer | Length: 7.5088306175948m | Houses: 1, Infrastructure P007997 | Type: a_remplacer | Length: 30.1295771789513m | Houses: 1, Infrastructure P007476 | Type: a_remplacer | Length: 4.92849119929359m | Houses: 1, Infrastructure P005500 | Type: a_remplacer | Length: 13.1420349052071m | Houses: 1, Infrastructure P007991 | Type: a_remplacer | Length: 7.5088306175948m | Houses: 1, Infrastructure P007997 | Type: a_remplacer | Length: 30.1295771789513m | Houses: 1, Infrastructure P007572 | Type: a_remplacer | Length: 5.62700791605979m | Houses: 1, Infrastructure P005500 | Type: a_remplacer | Length: 13.1420349052071m | Houses: 1, Infrastructure P007991 | Type: a_remplacer | Length: 7.5088306175948m | Houses: 1, Infrastructure P007998 | Type: a_remplacer | Length: 37.0636340148083m | Houses: 1, Infrastructure P007554 | Type: a_remplacer | Length: 8.72690474251765m | Houses: 1, Infrastructure P005770 | Type: a_remplacer | Length: 13.8935987811649m | Houses: 1, Infrastructure P007985 | Type: a_remplacer | Length: 10.4897301634131m | Houses: 1, Infrastructure P007813 | Type: a_remplacer | Length: 1.36523196955369m | Houses: 1, Infrastructure P005664 | Type: a_remplacer | Length: 12.9108403618454m | Houses: 1, Infrastructure P007448 | Type: a_remplacer | Length: 7.9742290455672m | Houses: 1, Infrastructure P005117 | Type: a_remplacer | Length: 13.2627025810985m | Houses: 1, Infrastructure P000873 | Type: a_remplacer | Length: 5.46510947034025m | Houses: 1, Infrastructure P007790 | Type: a_remplacer | Length: 5.85611808756648m | Houses: 1, Infrastructure P005317 | Type: a_remplacer | Length: 11.95171127553m | Houses: 1, Infrastructure P001156 | Type: a_remplacer | Length: 13.4887076792516m | Houses: 1, Infrastructure P007679 | Type: a_remplacer | Length: 4.5706986139249m | Houses: 1, Infrastructure P005317 | Type: a_remplacer | Length: 11.95171127553m | Houses: 1, Infrastructure P007999 | Type: a_remplacer | Length: 42.1144223056854m | Houses: 1, Infrastructure P007485 | Type: a_remplacer | Length: 5.64944506755882m | Houses: 1, Infrastructure P005117 | Type: a_remplacer | Length: 13.2627025810985m | Houses: 1, Infrastructure P008002 | Type: a_remplacer | Length: 12.5346743139761m | Houses: 1, Infrastructure P008006 | Type: a_remplacer | Length: 17.952854 ...
# [Building E000003 | [Infrastructure P007113 | Type: a_remplacer | Length: 12.1935087083631m | Houses: 1, Infrastructure P007984 | Type: a_remplacer | Length: 30.0575979492587m | Houses: 1, Infrastructure P007823 | Type: a_remplacer | Length: 12.290282829583m | Houses: 1], Building E000067 | [Infrastructure P006193 | Type: a_remplacer | Length: 12.1863879405322m | Houses: 1, Infrastructure P002851 | Type: a_remplacer | Length: 10.8032015604234m | Houses: 1, Infrastructure P007624 | Type: a_remplacer | Length: 4.10990474598487m | Houses: 1], Building E000085 | [Infrastructure P005500 | Type: a_remplacer | Length: 13.1420349052071m | Houses: 1, Infrastructure P007990 | Type: a_remplacer | Length: 18.7028610321555m | Houses: 1, Infrastructure P007447 | Type: a_remplacer | Length: 2.84535154473363m | Houses: 1], Building E000098 | [Infrastructure P005531 | Type: a_remplacer | Length: 14.8493095953268m | Houses: 1, Infrastructure P007639 | Type: a_remplacer | Length: 6.13280316452202m | Houses: 1], Building E000106 | [Infrastructure P005500 | Type: a_remplacer | Length: 13.1420349052071m | Houses: 1, Infrastructure P007990 | Type: a_remplacer | Length: 18.7028610321555m | Houses: 1, Infrastructure P001391 | Type: a_remplacer | Length: 7.63593644945982m | Houses: 1, Infrastructure P007752 | Type: a_remplacer | Length: 3.12835142463862m | Houses: 1], Building E000107 | [Infrastructure P005500 | Type: a_remplacer | Length: 13.1420349052071m | Houses: 1, Infrastructure P007990 | Type: a_remplacer | Length: 18.7028610321555m | Houses: 1, Infrastructure P001391 | Type: a_remplacer | Length: 7.63593644945982m | Houses: 1, Infrastructure P007689 | Type: a_remplacer | Length: 5.1037127857757m | Houses: 1], Building E000108 | [Infrastructure P005500 | Type: a_remplacer | Length: 13.1420349052071m | Houses: 1, Infrastructure P007991 | Type: a_remplacer | Length: 7.5088306175948m | Houses: 1, Infrastructure P007997 | Type: a_remplacer | Length: 30.1295771789513m | Houses: 1, Infrastructure P007476 | Type: a_remplacer | Length: 4.92849119929359m | Houses: 1], Building E000109 | [Infrastructure P005500 | Type: a_remplacer | Length: 13.1420349052071m | Houses: 1, Infrastructure P007991 | Type: a_remplacer | Length: 7.5088306175948m | Houses: 1, Infrastructure P007997 | Type: a_remplacer | Length: 30.1295771789513m | Houses: 1, Infrastructure P007572 | Type: a_remplacer | Length: 5.62700791605979m | Houses: 1], Building E000110 | [Infrastructure P005500 | Type: a_remplacer | Length: 13.1420349052071m | Houses: 1, Infrastructure P007991 | Type: a_remplacer | Length: 7.5088306175948m | Houses: 1, Infrastructure P007998 | Type: a_remplacer | Length: 37.0636340148083m | Houses: 1, Infrastructure P007554 | Type: a_remplacer | Length: 8.72690474251765m | Houses: 1], Building E000111 | [Infrastructure P005770 | Type: a_remplacer | Length: 13.8935987811649m | Houses: 1, Infrastructure P007985 | Type: a_remplacer | Length: 10.4897301634131m | Houses: 1, Infrastructure P007813 | Type: a_remplacer | Length: 1.36523196955369m | Houses: 1], Building E000112 | [Infrastructure P005664 | Type: a_remplacer | Length: 12.9108403618454m | Houses: 1, Infrastructure P007448 | Type: a_remplacer | Length: 7.9742290455672m | Houses: 1], Building E000127 | [Infrastructure P005117 | Type: a_remplacer | Length: 13.2627025810985m | Houses: 1, Infrastructure P000873 | Type: a_remplacer | Length: 5.46510947034025m | Houses: 1, Infrastructure P007790 | Type: a_remplacer | Length: 5.85611808756648m | Houses: 1], Building E000128 | [Infrastructure P005317 | Type: a_remplacer | Length: 11.95171127553m | Houses: 1, Infrastructure P001156 | Type: a_remplacer | Length: 13.4887076792516m | Houses: 1, Infrastructure P007679 | Type: a_remplacer | Length: 4.5706986139249m | Houses: 1], Building E000129 | [Infrastructure P005317 | Type: a_remplacer | Length: 11.95171127553m | Houses: 1, Infrastructure P007999 | Type: a_remplacer | Length: 42.1144223056854m | Houses: 1, Infrastructure P00748 ...
# {'P007113': 12.1935087083631, 'P007984': 30.0575979492587, 'P007823': 12.290282829583, 'P006193': 12.1863879405322, 'P002851': 10.8032015604234, 'P007624': 4.10990474598487, 'P005500': 13.1420349052071, 'P007990': 18.7028610321555, 'P007447': 2.84535154473363, 'P005531': 14.8493095953268, 'P007639': 6.13280316452202, 'P001391': 7.63593644945982, 'P007752': 3.12835142463862, 'P007689': 5.1037127857757, 'P007991': 7.5088306175948, 'P007997': 30.1295771789513, 'P007476': 4.92849119929359, 'P007572': 5.62700791605979, 'P007998': 37.0636340148083, 'P007554': 8.72690474251765, 'P005770': 13.8935987811649, 'P007985': 10.4897301634131, 'P007813': 1.36523196955369, 'P005664': 12.9108403618454, 'P007448': 7.9742290455672, 'P005117': 13.2627025810985, 'P000873': 5.46510947034025, 'P007790': 5.85611808756648, 'P005317': 11.95171127553, 'P001156': 13.4887076792516, 'P007679': 4.5706986139249, 'P007999': 42.1144223056854, 'P007485': 5.64944506755882, 'P008002': 12.5346743139761, 'P008006': 17.9528543234573, 'P007737': 4.66009795790718, 'P008007': 6.84639309859005, 'P007638': 5.10207355361142, 'P005100': 6.25975675306654, 'P000732': 10.7871386086093, 'P008001': 9.80181343246892, 'P000719': 10.698159350814, 'P000644': 5.79686473036686, 'P007802': 4.65316558492902, 'P008005': 8.40245186934037, 'P000723': 13.1599422339419, 'P000600': 9.68226549663264, 'P007641': 6.69156313094176, 'P008009': 25.2059107325926, 'P000604': 4.98282106064181, 'P007580': 8.43108274854405, 'P008008': 34.1154172411379, 'P008021': 14.9117118858221, 'P007785': 8.13675729756796, 'P008022': 34.8372572653182, 'P007595': 10.0082136912815, 'P008015': 34.6108377868067, 'P008023': 11.2796548571624, 'P007562': 10.7507961303452, 'P008024': 18.3100645954404, 'P007566': 6.60727277655205, 'P008003': 16.9947899061457, 'P008004': 4.2679056836056, 'P000494': 4.84007013228732, 'P000750': 5.4200839327337, 'P007727': 6.32141109105695, 'P005000': 2.71913580007238, 'P008027': 20.455789433764, 'P007530': 12.7359304342272, 'P008028': 36.9797725156077, 'P007593': 10.402928114011, 'P006106': 12.8869548736554, 'P002717': 6.93113318288768, 'P007565': 6.4644213871373, 'P005915': 12.8261922697184, 'P002445': 6.96033389014315, 'P007764': 4.11611330130554, 'P008026': 12.0182044137484, 'P007607': 7.64056605573305, 'P000748': 4.62412685627937, 'P007763': 6.65725214040895, 'P008010': 7.57564714734482, 'P008014': 13.8302331906613, 'P007695': 4.38499382431335, 'P005820': 14.5718479009645, 'P007627': 8.53830202306228, 'P000744': 5.56320770970003, 'P007458': 6.8843047480427, 'P007686': 7.59049553958964, 'P008012': 2.80432575486411, 'P008011': 10.0806400820172, 'P007810': 0.372684471449813, 'P007731': 3.79968906454059, 'P007988': 17.9351395403247, 'P007698': 9.47252997174691, 'P005193': 14.491126102841, 'P007992': 10.3986057299725, 'P007648': 3.39796783687204, 'P008013': 8.28759638847956, 'P000740': 5.23566836620947, 'P007702': 4.73832300241692, 'P006709': 13.4212136147779, 'P008025': 10.7673305164675, 'P007692': 9.64962873769354, 'P006457': 9.77631599620947, 'P003569': 8.31138115880164, 'P007777': 8.95144561872574, 'P007696': 14.6793721892947, 'P005781': 14.510677085006, 'P007539': 6.64993672554073, 'P000476': 4.08484495788828, 'P000717': 5.06471817304192, 'P007618': 3.98512786168602, 'P003849': 4.45174541295179, 'P007713': 14.7479475229988, 'P005726': 13.6049409361135, 'P007994': 5.03354509521443, 'P003202': 3.57039201834049, 'P007597': 6.31480197224767, 'P000730': 1.29899271965775, 'P007631': 4.7919164305287, 'P008016': 8.04338585809972, 'P008020': 11.7528304195152, 'P007567': 4.70550586894857, 'P007995': 20.6914541519515, 'P003330': 1.95148972393884, 'P007770': 3.21575403753504, 'P007996': 9.96720012610787, 'P007662': 1.45309505359909, 'P000470': 2.57224945914596, 'P000635': 5.16644492273189, 'P007584': 3.081639376471, 'P006712': 12.5562775429942, 'P003802': 12.5012019609488, 'P007602': 11.2388526888587, 'P008029': 32.2334229767792, 'P003934': 6.60463481490573, 'P007552': 8.33224937288682, 'P008030': 10.1 ...
# {'E000112': 20.8850694074126, 'E000098': 20.982112759848818, 'E000274': 21.160613810546728, 'E000222': 23.11014992402678, 'E000188': 23.902639461167087, 'E000127': 24.58393013900523, 'E000364': 24.71856093749173, 'E000111': 25.74856091413169, 'E000185': 26.28250944368038, 'E000267': 27.03914277373685, 'E000067': 27.09949424694047, 'E000301': 28.523680021916093, 'E000365': 29.71178206108987, 'E000128': 30.0111175687065, 'E000268': 32.76706934430581, 'E000266': 33.83817286893894, 'E000085': 34.69024748209623, 'E000183': 35.910855668063576, 'E000322': 36.2963321928017, 'E000145': 37.74584354727607, 'E000252': 41.979517413036106, 'E000106': 42.609183811461044, 'E000346': 43.32315257795272, 'E000293': 43.38823706719599, 'E000315': 44.49718394475332, 'E000107': 44.58454517259812, 'E000144': 48.41032917643908, 'E000359': 48.47183163484366, 'E000184': 50.101836429691076, 'E000373': 50.62485375340443, 'E000316': 50.750235362986395, 'E000374': 51.42216134679751, 'E000360': 52.43455498631722, 'E000367': 54.2528278317595, 'E000003': 54.541389487204796, 'E000361': 54.61176647479549, 'E000368': 54.91726745059184, 'E000108': 55.70893390104679, 'E000109': 56.40745061781299, 'E000376': 57.82972382983484, 'E000369': 58.41242009852381, 'E000146': 58.695057811068644, 'E000129': 59.715578648774226, 'E000377': 59.92428313942433, 'E000366': 60.84083562235766, 'E000378': 63.053739864144575, 'E000380': 65.39698489140947, 'E000110': 66.44140428012786, 'E000372': 67.12588637038832, 'E000381': 72.83317519487603, 'E000375': 73.70029646817451, 'E000194': 75.09373628991753, 'E000195': 75.09373628991753, 'E000196': 75.09373628991753, 'E000225': 75.09373628991753, 'E000258': 75.09373628991753, 'E000259': 75.09373628991753, 'E000178': 75.39112889078802, 'E000160': 75.48309087581544, 'E000325': 75.81059670876895, 'E000197': 79.77108299597302, 'E000379': 81.17059990595115, 'E000326': 82.9627580580987, 'E000228': 84.48293132267332, 'E000161': 84.56913455607759, 'E000226': 85.20512214063302, 'E000227': 85.91131293217997, 'E000229': 87.9099359157641, 'E000198': 89.44050802931686, 'E000260': 92.29119452631225, 'E000275': 95.4518941503021, 'E000302': 98.23154080177981, 'E000257': 103.38143595960307, 'E000317': 105.26576773202272, 'E000327': 109.93379601869844, 'E000303': 110.90377026213764, 'E000358': 114.69232671875325, 'E000174': 116.273148672769, 'E000363': 117.68103026467884, 'E000370': 122.91293847697881, 'E000176': 127.79651952120602, 'E000177': 130.68340590569088, 'E000371': 136.33695371405642, 'E000175': 138.0701504459786, 'E000193': 147.72070722417857}

# %%
#Redéfinition de la classe Infra
class Infra:

    def __init__(self,infra_id,length,infra_type,nb_house,cost,time):
        self.infra_id = infra_id
        self.length = length
        self.infra_type = infra_type
        self.nb_house = nb_house
        self.cost = cost
        self.time = time

    def __repr__(self):
        return f"Infrastructure {self.infra_id} | Type: {self.infra_type} | Length: {self.length}m | Houses: {self.nb_house} | cost: {self.cost} | time: {self.time}"

    def repair_infra(self) :
        pass

    def get_infra_difficulty(self) :
        return self.cost*self.time/self.nb_house

# %%
#2éme script : Calcul de la nouvelle métrique.

#Méthode de lecture et de normalisation du fichier annexe 
def extract_infra_costs_and_times(appendix):
    doc = Document(appendix)
    text = "\n".join([p.text for p in doc.paragraphs])
    
    prix_dict = {}
    duree_dict = {}
    current = None
    
    for line in text.splitlines():
        line = line.strip().lower()
        if not line:
            continue
        if "prix" in line:
            current = "prix"
            continue
        if "durée" in line or "duree" in line:
            current = "duree"
            continue

        if ":" in line:
            type_infra, val = line.split(":", 1)
            type_infra = type_infra.strip()
            val = val.strip().split(" ")[0]
            val_numeric = ''.join(c for c in val if c.isdigit() or c == ".")
            if not val_numeric:  # ignore si rien de numérique
                continue
            if current == "prix":
                prix_dict[type_infra] = float(val_numeric)
            elif current == "duree":
                duree_dict[type_infra] = float(val_numeric)
    
    return prix_dict, duree_dict


#Méthode regroupant tout les informations essentielles au calcul de la métrique :
def complete_data(buildings,infra,network,appendix) :


    buildings_csv = pd.read_csv(buildings)
    infra_csv = pd.read_csv(infra)
    network_xlsx = pd.read_excel(network)
    prix_dict, duree_dict = extract_infra_costs_and_times(appendix)

    
    #Corriger le nombre des maisons pour chaque batiment
    buildings_correction = pd.merge(network_xlsx, buildings_csv, on="id_batiment", how="left", suffixes=("", "_csv1"))
    buildings_correction["nb_maisons"] = buildings_correction["nb_maisons_csv1"].combine_first(buildings_correction["nb_maisons"])
    buildings_correction = buildings_correction.drop(columns=["nb_maisons_csv1"])


    #Ajouter la colonne type_infra pour chaque infra
    infra_type = pd.merge(buildings_correction, infra_csv[["id_infra", "type_infra"]], left_on="infra_id",right_on="id_infra",how="left")
    infra_type = infra_type.drop(columns=["id_infra"])

    #Ajouter les colonnes de coût et durée pour reconstruire chaque infra
    infra_type["cout_total"] = infra_type["type_infra"].str.lower().map(prix_dict) * infra_type["longueur"]
    infra_type["duree_totale"] = infra_type["type_infra"].str.lower().map(duree_dict) * infra_type["longueur"]
    complete_data = infra_type.drop_duplicates()


    return complete_data


#Méthode calculant la métrique de difficulté pour chaque batiment: 
def final_metric(complete_data):

    broken_infra = []
    buildings_without_electricity = []
    buildings = {}
    infra_difficulties = {}
    building_difficulties = {}


    complete_data = complete_data[complete_data["infra_type"] == "a_remplacer"]
    for _,infra in complete_data.iterrows():
        infrastructure = Infra(infra_id=infra["infra_id"], length=infra["longueur"], infra_type=infra["infra_type"], nb_house=infra["nb_maisons"], cost=infra["cout_total"]
                               ,time=infra["duree_totale"])
        broken_infra.append(infrastructure)
    for infra, building_id in zip(broken_infra, complete_data["id_batiment"]):
        if building_id not in buildings:
            buildings[building_id] = Building(id_building=building_id, list_infra=[])
        buildings[building_id].list_infra.append(infra)
    buildings_without_electricity = list(buildings
                                         .values())
    
    for infra in broken_infra :
        infra_difficulties[infra.infra_id] = infra.get_infra_difficulty()
    

    for building in buildings_without_electricity :
        building_difficulties[building.id_building] = building.get_building_difficulty()
    
    final_result = dict(sorted(building_difficulties.items(), key=lambda item: item[1]))
  
    return final_result

# %%
#Difficulté de chaque batiment en euros.heure/nbr_maisons
data = complete_data("batiments.csv","infra.csv","reseau_en_arbre.xlsx","annexe.docx")
final_metric(data)
# Out:
# {'E000112': 38379.68795337064,
#  'E000364': 44508.741467693544,
#  'E000127': 45011.279628416785,
#  'E000259': 45759.1342536561,
#  'E000098': 55678.96162919077,
#  'E000258': 61012.17900487479,
#  'E000111': 62290.77769626339,
#  'E000274': 63695.351979753395,
#  'E000128': 64577.08245465618,
#  'E000302': 68142.4824660393,
#  'E000222': 71841.09259332197,
#  'E000266': 71926.29820878938,
#  'E000194': 73214.61480584975,
#  'E000225': 73214.61480584975,
#  'E000365': 80051.69597182679,
#  'E000195': 91518.2685073122,
#  'E000160': 93547.70416614751,
#  'E000373': 107938.81480704871,
#  'E000381': 111463.31918377968,
#  'E000268': 119109.43661642613,
#  'E000196': 122024.35800974959,
#  'E000376': 126111.58203327718,
#  'E000378': 136981.5768470732,
#  'E000301': 142706.44978791545,
#  'E000316': 148004.7665223368,
#  'E000293': 150686.87624582407,
#  'E000315': 163179.16379889174,
#  'E000228': 166486.74171622988,
#  'E000377': 170776.25132296403,
#  'E000374': 187638.69966126635,
#  'E000346': 189172.57231049918,
#  'E000322': 198412.46720908975,
#  'E000197': 206497.84431784315,
#  'E000260': 211613.8358033693,
#  'E000267': 214937.58895480935,
#  'E000144': 217159.97287004982,
#  'E000146': 232316.28230686177,
#  'E000252': 253415.05326144845,
#  'E000067': 258826.25963841038,
#  'E000359': 267220.2694109377,
#  'E000184': 285724.5689732736,
#  'E000380': 295370.85163000436,
#  'E000188': 296403.5192045903,
#  'E000145': 348981.28146090265,
#  'E000371': 370211.00124841154,
#  'E000129': 402443.33145386743,
#  'E000107': 405470.92050417175,
#  'E000185': 424045.08218127897,
#  'E000227': 424427.3622926125,
#  'E000303': 465495.0035704902,
#  'E000358': 476497.4786577572,
#  'E000226': 502255.2677181747,
#  'E000368': 554552.3453017756,
#  'E000085': 558942.2065968337,
#  'E000327': 614772.3554379945,
#  'E000110': 714287.4547208382,
#  'E000161': 733185.9639399853,
#  'E000109': 757193.1852590976,
#  'E000108': 770133.5013706668,
#  'E000366': 778186.174120569,
#  'E000106': 794680.5394446917,
#  'E000198': 839449.7873915834,
#  'E000193': 869761.1249993393,
#  'E000317': 872257.1637978423,
#  'E000178': 932447.9544800178,
#  'E000370': 1003656.1240667305,
#  'E000363': 1022847.9246744824,
#  'E000372': 1023928.8503952932,
#  'E000175': 1095949.1874081586,
#  'E000003': 1203191.90113135,
#  'E000325': 1286088.7095113946,
#  'E000229': 1396238.278453522,
#  'E000326': 1413039.5053752318,
#  'E000275': 1452109.5678954432,
#  'E000367': 1475500.043016339,
#  'E000369': 1625092.4158773671,
#  'E000257': 1809176.0753010204,
#  'E000174': 2062286.0152687405,
#  'E000183': 2067361.9686363894,
#  'E000360': 2230873.9929019785,
#  'E000379': 2636272.7385696876,
#  'E000176': 3682203.871114696,
#  'E000177': 4083861.4791622562,
#  'E000361': 4660508.533225851,
#  'E000375': 4964860.121946329}

# %%
# Constantes
MAX_WORKERS = 4
WORKER_COST_PER_HOUR = 300 / 8  # €/heure
HOSPITAL_MARGIN = 1.2  # marge de sécurité pour l'hôpital (16h de travaux)
GENERATOR_AVAILABLE_HOURS = 20

# %%
PHASE_COST_PERCENTAGE = {
    0: 1.0,   # phase 0 = hôpital
    1: 0.4,   # phase 1 = 40% du coût
    2: 0.2,   # phase 2 = 20%
    3: 0.2,   # phase 3 = 20%
    4: 0.2    # phase 4 = 20%
}

# %%
#Redéfinition de la classe Infra pour pouvoir calculer la nouvelle métrique
class Infra:
    def __init__(self, infra_id, length, infra_type, nb_house, cost,time):
        self.infra_id = infra_id
        self.length = length
        self.infra_type = infra_type
        self.nb_house = nb_house
        self.cost = cost
        self.time = time

    def get_difficulty(self):
        """Calcul de la difficulté d'une infra"""
        effective_time = self.time / MAX_WORKERS
        difficulty = (effective_time * self.cost) / self.nb_house
        return difficulty

    def __repr__(self):
        return f"Infra({self.infra_id}, type={self.infra_type}, houses={self.nb_house})"

# %%
#Redéfinition de la classe Infra pour pouvoir calculer la nouvelle métrique

class Building:
    def __init__(self, id_building):
        self.id_building = id_building
        self.list_infra = []

    def add_infra(self, infra):
        self.list_infra.append(infra)

    def get_building_difficulty(self):
        return sum(i.get_difficulty() for i in self.list_infra if i.infra_type == "a_remplacer")

# %%
#Calcul du cout et de la durée essentielle pour la phase 0 et donc la réparation de l'hopital
def phase_0(hopital_infra_list):

    total_effective_time = 0
    total_cost = 0
    total_effective_timee = []

    for infra in hopital_infra_list:
        effective_time = infra.time / MAX_WORKERS
        total_cost += infra.cost
        total_effective_timee.append(effective_time)
        print(f"Infra {infra.infra_id} | Temps effectif : {effective_time:.2f} h | Coût : {infra.cost:.2f} €")
    
    total_effective_time = max(total_effective_timee)


    print(f"\nTemps total estimé : {total_effective_time:.2f} h")
    print(f"Coût total : {total_cost:.2f} €")

    # On vérifie si le générateur tiendra
    if total_effective_time > GENERATOR_AVAILABLE_HOURS:
        print("Attention : le générateur risque de tomber en panne avant la fin des travaux !")
        print(f"Autonomie restante : {GENERATOR_AVAILABLE_HOURS} h | Temps requis : {total_effective_time:.2f} h")
    else:
        print("Le générateur pourra tenir pendant toute la phase 0.")

    return {
        "total_time": total_effective_time,
        "total_cost": total_cost
    }

# %%
hospital_rows = data[data["type_batiment"] == "hôpital"]
hospital_rows = hospital_rows[hospital_rows["infra_type"] == "a_remplacer"]
hopital_infra_list = [
    Infra(
        infra_id=row["infra_id"],
        length=row["longueur"],
        infra_type=row["type_infra"],
        nb_house=row["nb_maisons"],
        cost=row["cout_total"],
        time=row["duree_totale"]
    )
    for _, row in hospital_rows.iterrows()
]

result_phase0 = phase_0(hopital_infra_list)
# Out:
# Infra P005500 | Temps effectif : 6.57 h | Coût : 6571.02 €
# Infra P007990 | Temps effectif : 9.35 h | Coût : 9351.43 €
# Infra P007447 | Temps effectif : 3.56 h | Coût : 2560.82 €
#
# Temps total estimé : 9.35 h
# Coût total : 18483.26 €
# Le générateur pourra tenir pendant toute la phase 0.

# %%
def plan_phases_by_building_once(df):
    # On crée les bâtiments et leur liste d'infra
    buildings = {}
    for _, row in df.iterrows():
        b_id = row["id_batiment"]
        if b_id not in buildings:
            buildings[b_id] = Building(b_id)
        infra = Infra(
            infra_id=row["infra_id"],
            length=row["longueur"],
            infra_type=row["infra_type"],
            nb_house=row["nb_maisons"],
            cost=row["cout_total"],
            time=row["duree_totale"]
        )
        buildings[b_id].add_infra(infra)

    # On calcule la difficulté de chaque bâtiment
    building_difficulties = {b.id_building: b.get_building_difficulty() for b in buildings.values()}

    # On trie les bâtiments par difficulté croissante
    sorted_buildings = sorted(buildings.values(), key=lambda b: b.get_building_difficulty())

    # On initialise les phases
    phases = {1: [], 2: [], 3: [], 4: []}
    PHASE_COST_PERCENTAGE = {1: 0.4, 2: 0.2, 3: 0.2, 4: 0.2}
    phase_index = 1
    assigned_cost = 0
    total_cost = sum(i.cost for b in buildings.values() for i in b.list_infra if i.infra_type == "a_remplacer")

    # On répartit les infra dans les phases en suivant la difficulté des bâtiments
    for building in sorted_buildings:
        building_infra = [i for i in building.list_infra if i.infra_type == "a_remplacer"]
        building_cost = sum(i.cost for i in building_infra)

        # Passer à la phase suivante si le coût cumulé dépasse la limite
        if assigned_cost + building_cost > total_cost * PHASE_COST_PERCENTAGE.get(phase_index, 0):
            phase_index += 1
            if phase_index > 4:
                phase_index = 4
            assigned_cost = 0

        phases[phase_index].extend(building_infra)
        assigned_cost += building_cost

    # Difficulté de chaque infra
    infra_difficulties = {
        i.infra_id: i.get_difficulty()
        for b in buildings.values() for i in b.list_infra
    }

    # On affiche les résultas résumé
    for idx in range(1, 5):
        phase_infra = phases[idx]
        print(f"\n Phase {idx} | Infra à remplacer : {len(phase_infra)}")
        for i in phase_infra:
            print(f"  {i.infra_id} | Difficulté : {i.get_difficulty():.2f} | "
                  f"Coût : {i.cost:.2f} | Durée : {i.time:.2f} h")

    return phases, building_difficulties, infra_difficulties

# %%
phases_result,building_difficulties,infra_difficulties  = plan_phases_by_building_once(data)  
print(building_difficulties)
print(infra_difficulties)
# Out:
#  Phase 1 | Infra à remplacer : 229
#   P005664 | Difficulté : 6945.41 | Coût : 6455.42 | Durée : 25.82 h
#   P007448 | Difficulté : 2649.51 | Coût : 3987.11 | Durée : 15.95 h
#   P004862 | Difficulté : 3890.93 | Coût : 4410.74 | Durée : 17.64 h
#   P008031 | Difficulté : 6026.85 | Coût : 5489.47 | Durée : 21.96 h
#   P007518 | Difficulté : 1209.41 | Coût : 2459.07 | Durée : 9.84 h
#   P005117 | Difficulté : 5496.85 | Coût : 6631.35 | Durée : 26.53 h
#   P000873 | Difficulté : 933.36 | Coût : 2732.55 | Durée : 10.93 h
#   P007790 | Difficulté : 4822.61 | Coût : 5270.51 | Durée : 29.28 h
#   P005100 | Difficulté : 1224.52 | Coût : 3129.88 | Durée : 12.52 h
#   P000732 | Difficulté : 3636.32 | Coût : 5393.57 | Durée : 21.57 h
#   P008001 | Difficulté : 3002.36 | Coût : 4900.91 | Durée : 19.60 h
#   P000719 | Difficulté : 3576.58 | Coût : 5349.08 | Durée : 21.40 h
#   P005531 | Difficulté : 7875.07 | Coût : 7424.65 | Durée : 29.70 h
#   P007639 | Difficulté : 6044.67 | Coût : 5519.52 | Durée : 30.66 h
#   P005100 | Difficulté : 1632.69 | Coût : 3129.88 | Durée : 12.52 h
#   P000732 | Difficulté : 4848.43 | Coût : 5393.57 | Durée : 21.57 h
#   P008001 | Difficulté : 4003.15 | Coût : 4900.91 | Durée : 19.60 h
#   P000719 | Difficulté : 4768.78 | Coût : 5349.08 | Durée : 21.40 h
#   P005770 | Difficulté : 9651.60 | Coût : 6946.80 | Durée : 27.79 h
#   P007985 | Difficulté : 5501.72 | Coût : 5244.87 | Durée : 20.98 h
#   P007813 | Difficulté : 419.37 | Coût : 1228.71 | Durée : 6.83 h
#   P005781 | Difficulté : 13159.98 | Coût : 7255.34 | Durée : 29.02 h
#   P007539 | Difficulté : 2763.85 | Coût : 3324.97 | Durée : 13.30 h
#   P005317 | Difficulté : 5951.81 | Coût : 5975.86 | Durée : 23.90 h
#   P001156 | Difficulté : 7581.05 | Coût : 6744.35 | Durée : 26.98 h
#   P007679 | Difficulté : 2611.41 | Coût : 3428.02 | Durée : 18.28 h
#   P005100 | Difficulté : 1399.45 | Coût : 3129.88 | Durée : 12.52 h
#   P000732 | Difficulté : 4155.80 | Coût : 5393.57 | Durée : 21.57 h
#   P008001 | Difficulté : 3431.27 | Coût : 4900.91 | Durée : 19.60 h
#   P000719 | Difficulté : 4087.52 | Coût : 5349.08 | Durée : 21.40 h
#   P000730 | Difficulté : 271.19 | Coût : 1169.09 | Durée : 6.49 h
#   P007631 | Difficulté : 3690.40 | Coût : 4312.72 | Durée : 23.96 h
#   P005820 | Difficulté : 8847.45 | Coût : 7285.92 | Durée : 29.14 h
#   P007627 | Difficulté : 9112.83 | Coût : 6403.73 | Durée : 34.15 h
#   P006709 | Difficulté : 5629.03 | Coût : 6710.61 | Durée : 26.84 h
#   P008025 | Difficulté : 3622.98 | Coût : 5383.67 | Durée : 21.53 h
#   P007692 | Difficulté : 8729.56 | Coût : 7237.22 | Durée : 38.60 h
#   P005100 | Difficulté : 1959.23 | Coût : 3129.88 | Durée : 12.52 h
#   P000732 | Difficulté : 5818.12 | Coût : 5393.57 | Durée : 21.57 h
#   P008001 | Difficulté : 4803.78 | Coût : 4900.91 | Durée : 19.60 h
#   P000719 | Difficulté : 5722.53 | Coût : 5349.08 | Durée : 21.40 h
#   P005100 | Difficulté : 1959.23 | Coût : 3129.88 | Durée : 12.52 h
#   P000732 | Difficulté : 5818.12 | Coût : 5393.57 | Durée : 21.57 h
#   P008001 | Difficulté : 4803.78 | Coût : 4900.91 | Durée : 19.60 h
#   P000719 | Difficulté : 5722.53 | Coût : 5349.08 | Durée : 21.40 h
#   P004862 | Difficulté : 2431.83 | Coût : 4410.74 | Durée : 17.64 h
#   P008031 | Difficulté : 3766.78 | Coût : 5489.47 | Durée : 21.96 h
#   P007780 | Difficulté : 13814.31 | Coût : 8920.23 | Durée : 49.56 h
#   P005100 | Difficulté : 2449.03 | Coût : 3129.88 | Durée : 12.52 h
#   P000732 | Difficulté : 7272.65 | Coût : 5393.57 | Durée : 21.57 h
#   P008001 | Difficulté : 6004.72 | Coût : 4900.91 | Durée : 19.60 h
#   P000719 | Difficulté : 7153.16 | Coût : 5349.08 | Durée : 21.40 h
#   P005100 | Difficulté : 1224.52 | Coût : 3129.88 | Durée : 12.52 h
#   P000732 | Difficulté : 3636.32 | Coût : 5393.57 | Durée : 21.57 h
#   P008001 | Difficulté : 3002.36 | Coût : 4900.91 | Durée : 19.60 h
#   P000719 | Difficulté : 3576.58 | Coût : 5349.08 | Durée : 21.40 h
#   P008005 | Difficulté : 2206.29 | Coût : 4201.23 | Durée : 16.80 h
#   P000723 | Difficulté : 5412.00 | Coût : 6579.97 | Durée : 26.32 h
#   P000600 | Difficulté : 2929.57 | Coût : 4841.13 | Durée : 19.36 h
#   P007641 | Difficulté : 1399.28 | Coût : 3345.78 | Durée : 13.38 h
#   P004862 | Difficulté : 2431.83 | Coût : 4410.74 | Durée : 17.64 h
#   P008031 | Difficulté : 3766.78 | Coût : 5489.47 | Durée : 21.96 h
#   P008032 | Difficulté : 3459.09 | Coût : 5260.49 | Durée : 21.04 h
#   P004209 | Difficulté : 13993.66 | Coût : 8977.94 | Durée : 49.88 h
#   P007514 | Difficulté : 3333.34 | Coût : 5163.98 | Durée : 20.66 h
#   P004862 | Difficulté : 2431.83 | Coût : 4410.74 | Durée : 17.64 h
#   P008031 | Difficulté : 3766.78 | Coût : 5489.47 | Durée : 21.96 h
#   P008032 | Difficulté : 3459.09 | Coût : 5260.49 | Durée : 21.04 h
#   P008035 | Difficulté : 4292.27 | Coût : 5859.88 | Durée : 23.44 h
#   P004234 | Difficulté : 5682.58 | Coût : 6742.45 | Durée : 26.97 h
#   P008036 | Difficulté : 5191.86 | Coût : 5581.32 | Durée : 29.77 h
#   P007459 | Difficulté : 3041.42 | Coût : 4932.68 | Durée : 19.73 h
#   P006457 | Difficulté : 17920.57 | Coût : 8798.68 | Durée : 48.88 h
#   P003569 | Difficulté : 2878.29 | Coût : 4155.69 | Durée : 16.62 h
#   P007696 | Difficulté : 8978.50 | Coût : 7339.69 | Durée : 29.36 h
#   P005100 | Difficulté : 3265.38 | Coût : 3129.88 | Durée : 12.52 h
#   P000732 | Difficulté : 9696.86 | Coût : 5393.57 | Durée : 21.57 h
#   P008001 | Difficulté : 8006.30 | Coût : 4900.91 | Durée : 19.60 h
#   P000719 | Difficulté : 9537.55 | Coût : 5349.08 | Durée : 21.40 h
#   P004862 | Difficulté : 2431.83 | Coût : 4410.74 | Durée : 17.64 h
#   P008031 | Difficulté : 3766.78 | Coût : 5489.47 | Durée : 21.96 h
#   P008032 | Difficulté : 3459.09 | Coût : 5260.49 | Durée : 21.04 h
#   P004209 | Difficulté : 13993.66 | Coût : 8977.94 | Durée : 49.88 h
#   P004211 | Difficulté : 1161.99 | Coût : 2587.09 | Durée : 14.37 h
#   P007506 | Difficulté : 6714.54 | Coût : 7329.14 | Durée : 29.32 h
#   P004862 | Difficulté : 3890.93 | Coût : 4410.74 | Durée : 17.64 h
#   P008031 | Difficulté : 6026.85 | Coût : 5489.47 | Durée : 21.96 h
#   P008032 | Difficulté : 5534.55 | Coût : 5260.49 | Durée : 21.04 h
#   P008035 | Difficulté : 6867.64 | Coût : 5859.88 | Durée : 23.44 h
#   P004234 | Difficulté : 9092.13 | Coût : 6742.45 | Durée : 26.97 h
#   P007497 | Difficulté : 2833.30 | Coût : 3763.84 | Durée : 15.06 h
#   P005726 | Difficulté : 15424.53 | Coût : 6802.47 | Durée : 27.21 h
#   P007994 | Difficulté : 2111.38 | Coût : 2516.77 | Durée : 10.07 h
#   P003202 | Difficulté : 3186.92 | Coût : 2677.79 | Durée : 14.28 h
#   P007597 | Difficulté : 14953.77 | Coût : 5683.32 | Durée : 31.57 h
#   P005726 | Difficulté : 9254.72 | Coût : 6802.47 | Durée : 27.21 h
#   P007994 | Difficulté : 1266.83 | Coût : 2516.77 | Durée : 10.07 h
#   P007995 | Difficulté : 21406.81 | Coût : 10345.73 | Durée : 41.38 h
#   P007996 | Difficulté : 4967.25 | Coût : 4983.60 | Durée : 19.93 h
#   P007662 | Difficulté : 105.57 | Coût : 726.55 | Durée : 2.91 h
#   P006709 | Difficulté : 11258.06 | Coût : 6710.61 | Durée : 26.84 h
#   P008025 | Difficulté : 7245.96 | Coût : 5383.67 | Durée : 21.53 h
#   P003849 | Difficulté : 5573.82 | Coût : 4006.57 | Durée : 22.26 h
#   P007713 | Difficulté : 13593.87 | Coût : 7373.97 | Durée : 29.50 h
#   P005726 | Difficulté : 11568.40 | Coût : 6802.47 | Durée : 27.21 h
#   P007994 | Difficulté : 1583.54 | Coût : 2516.77 | Durée : 10.07 h
#   P007995 | Difficulté : 26758.52 | Coût : 10345.73 | Durée : 41.38 h
#   P003330 | Difficulté : 238.02 | Coût : 975.74 | Durée : 3.90 h
#   P007770 | Difficulté : 646.32 | Coût : 1607.88 | Durée : 6.43 h
#   P005100 | Difficulté : 1224.52 | Coût : 3129.88 | Durée : 12.52 h
#   P000732 | Difficulté : 3636.32 | Coût : 5393.57 | Durée : 21.57 h
#   P008001 | Difficulté : 3002.36 | Coût : 4900.91 | Durée : 19.60 h
#   P000719 | Difficulté : 3576.58 | Coût : 5349.08 | Durée : 21.40 h
#   P008003 | Difficulté : 9025.72 | Coût : 8497.39 | Durée : 33.99 h
#   P008004 | Difficulté : 2561.49 | Coût : 3841.12 | Durée : 21.34 h
#   P000494 | Difficulté : 732.07 | Coût : 2420.04 | Durée : 9.68 h
#   P008010 | Difficulté : 8070.53 | Coût : 6818.08 | Durée : 37.88 h
#   P008012 | Difficulté : 245.76 | Coût : 1402.16 | Durée : 5.61 h
#   P008011 | Difficulté : 9526.81 | Coût : 7560.48 | Durée : 40.32 h
#   P007810 | Difficulté : 19.53 | Coût : 335.42 | Durée : 1.86 h
#   P004862 | Difficulté : 3242.44 | Coût : 4410.74 | Durée : 17.64 h
#   P008031 | Difficulté : 5022.37 | Coût : 5489.47 | Durée : 21.96 h
#   P008032 | Difficulté : 4612.12 | Coût : 5260.49 | Durée : 21.04 h
#   P008035 | Difficulté : 5723.03 | Coût : 5859.88 | Durée : 23.44 h
#   P004196 | Difficulté : 11240.84 | Coût : 6968.53 | Durée : 38.71 h
#   P007703 | Difficulté : 12853.25 | Coût : 7605.24 | Durée : 40.56 h
#   P004862 | Difficulté : 2779.24 | Coût : 4410.74 | Durée : 17.64 h
#   P008031 | Difficulté : 4304.89 | Coût : 5489.47 | Durée : 21.96 h
#   P008032 | Difficulté : 3953.25 | Coût : 5260.49 | Durée : 21.04 h
#   P008034 | Difficulté : 16103.28 | Coût : 9008.91 | Durée : 50.05 h
#   P007534 | Difficulté : 19769.02 | Coût : 9981.78 | Durée : 55.45 h
#   P006712 | Difficulté : 25338.23 | Coût : 11300.65 | Durée : 62.78 h
#   P003802 | Difficulté : 5581.43 | Coût : 6250.60 | Durée : 25.00 h
#   P003870 | Difficulté : 1501.58 | Coût : 3242.07 | Durée : 12.97 h
#   P007699 | Difficulté : 14871.91 | Coût : 8836.15 | Durée : 47.13 h
#   P006712 | Difficulté : 35473.52 | Coût : 11300.65 | Durée : 62.78 h
#   P003802 | Difficulté : 7814.00 | Coût : 6250.60 | Durée : 25.00 h
#   P007602 | Difficulté : 6315.59 | Coût : 5619.43 | Durée : 22.48 h
#   P005100 | Difficulté : 2449.03 | Coût : 3129.88 | Durée : 12.52 h
#   P000732 | Difficulté : 7272.65 | Coût : 5393.57 | Durée : 21.57 h
#   P008001 | Difficulté : 6004.72 | Coût : 4900.91 | Durée : 19.60 h
#   P000719 | Difficulté : 7153.16 | Coût : 5349.08 | Durée : 21.40 h
#   P008003 | Difficulté : 18051.43 | Coût : 8497.39 | Durée : 33.99 h
#   P008004 | Difficulté : 5122.97 | Coût : 3841.12 | Durée : 21.34 h
#   P000494 | Difficulté : 1464.14 | Coût : 2420.04 | Durée : 9.68 h
#   P000748 | Difficulté : 1336.41 | Coût : 2312.06 | Durée : 9.25 h
#   P007763 | Difficulté : 2769.94 | Coût : 3328.63 | Durée : 13.31 h
#   P005100 | Difficulté : 1399.45 | Coût : 3129.88 | Durée : 12.52 h
#   P000732 | Difficulté : 4155.80 | Coût : 5393.57 | Durée : 21.57 h
#   P008001 | Difficulté : 3431.27 | Coût : 4900.91 | Durée : 19.60 h
#   P000719 | Difficulté : 4087.52 | Coût : 5349.08 | Durée : 21.40 h
#   P008003 | Difficulté : 10315.10 | Coût : 8497.39 | Durée : 33.99 h
#   P008004 | Difficulté : 2927.41 | Coût : 3841.12 | Durée : 21.34 h
#   P000494 | Difficulté : 836.65 | Coût : 2420.04 | Durée : 9.68 h
#   P008010 | Difficulté : 9223.46 | Coût : 6818.08 | Durée : 37.88 h
#   P008012 | Difficulté : 280.87 | Coût : 1402.16 | Durée : 5.61 h
#   P008013 | Difficulté : 11038.54 | Coût : 7458.84 | Durée : 41.44 h
#   P000740 | Difficulté : 4405.54 | Coût : 4712.10 | Durée : 26.18 h
#   P007702 | Difficulté : 801.85 | Coût : 2369.16 | Durée : 9.48 h
#   P006457 | Difficulté : 26880.85 | Coût : 8798.68 | Durée : 48.88 h
#   P003569 | Difficulté : 4317.44 | Coût : 4155.69 | Durée : 16.62 h
#   P007777 | Difficulté : 22536.11 | Coût : 8056.30 | Durée : 44.76 h
#   P005117 | Difficulté : 7329.14 | Coût : 6631.35 | Durée : 26.53 h
#   P008002 | Difficulté : 29459.64 | Coût : 11281.21 | Durée : 62.67 h
#   P008006 | Difficulté : 13429.37 | Coût : 8976.43 | Durée : 35.91 h
#   P007737 | Difficulté : 4071.85 | Coût : 4194.09 | Durée : 23.30 h
#   P005100 | Difficulté : 4898.07 | Coût : 3129.88 | Durée : 12.52 h
#   P000732 | Difficulté : 14545.29 | Coût : 5393.57 | Durée : 21.57 h
#   P008001 | Difficulté : 12009.44 | Coût : 4900.91 | Durée : 19.60 h
#   P000719 | Difficulté : 14306.33 | Coût : 5349.08 | Durée : 21.40 h
#   P000644 | Difficulté : 4200.46 | Coût : 2898.43 | Durée : 11.59 h
#   P007802 | Difficulté : 8119.48 | Coût : 3489.87 | Durée : 18.61 h
#   P005820 | Difficulté : 10616.94 | Coût : 7285.92 | Durée : 29.14 h
#   P007988 | Difficulté : 48250.38 | Coût : 13451.35 | Durée : 71.74 h
#   P007698 | Difficulté : 4486.44 | Coût : 4736.26 | Durée : 18.95 h
#   P006193 | Difficulté : 41767.89 | Coût : 10967.75 | Durée : 60.93 h
#   P002851 | Difficulté : 21882.97 | Coût : 8102.40 | Durée : 43.21 h
#   P007624 | Difficulté : 1055.71 | Coût : 2054.95 | Durée : 8.22 h
#   P006712 | Difficulté : 44341.90 | Coût : 11300.65 | Durée : 62.78 h
#   P003802 | Difficulté : 9767.50 | Coût : 6250.60 | Durée : 25.00 h
#   P003870 | Difficulté : 2627.76 | Coût : 3242.07 | Durée : 12.97 h
#   P003881 | Difficulté : 1879.84 | Coût : 2742.15 | Durée : 10.97 h
#   P007637 | Difficulté : 8188.06 | Coût : 5722.96 | Durée : 22.89 h
#   P005000 | Difficulté : 924.21 | Coût : 2039.35 | Durée : 10.88 h
#   P008028 | Difficulté : 56979.32 | Coût : 18489.89 | Durée : 73.96 h
#   P007593 | Difficulté : 13527.61 | Coût : 7802.20 | Durée : 41.61 h
#   P004862 | Difficulté : 4863.66 | Coût : 4410.74 | Durée : 17.64 h
#   P008031 | Difficulté : 7533.56 | Coût : 5489.47 | Durée : 21.96 h
#   P008032 | Difficulté : 6918.18 | Coût : 5260.49 | Durée : 21.04 h
#   P008035 | Difficulté : 8584.55 | Coût : 5859.88 | Durée : 23.44 h
#   P004196 | Difficulté : 16861.26 | Coût : 6968.53 | Durée : 38.71 h
#   P004185 | Difficulté : 2118.29 | Coût : 2910.87 | Durée : 11.64 h
#   P007463 | Difficulté : 26963.21 | Coût : 8812.15 | Durée : 48.96 h
#   P005915 | Difficulté : 61691.70 | Coût : 9619.64 | Durée : 51.30 h
#   P002445 | Difficulté : 6055.78 | Coût : 3480.17 | Durée : 13.92 h
#   P007764 | Difficulté : 6353.40 | Coût : 3087.08 | Durée : 16.46 h
#   P005117 | Difficulté : 14658.27 | Coût : 6631.35 | Durée : 26.53 h
#   P008002 | Difficulté : 58919.27 | Coût : 11281.21 | Durée : 62.67 h
#   P008007 | Difficulté : 3906.09 | Coût : 3423.20 | Durée : 13.69 h
#   P007638 | Difficulté : 9761.68 | Coût : 4591.87 | Durée : 25.51 h
#   P005100 | Difficulté : 1632.69 | Coût : 3129.88 | Durée : 12.52 h
#   P000732 | Difficulté : 4848.43 | Coût : 5393.57 | Durée : 21.57 h
#   P008001 | Difficulté : 4003.15 | Coût : 4900.91 | Durée : 19.60 h
#   P000719 | Difficulté : 4768.78 | Coût : 5349.08 | Durée : 21.40 h
#   P008003 | Difficulté : 12034.29 | Coût : 8497.39 | Durée : 33.99 h
#   P008004 | Difficulté : 3415.32 | Coût : 3841.12 | Durée : 21.34 h
#   P000494 | Difficulté : 976.09 | Coût : 2420.04 | Durée : 9.68 h
#   P008010 | Difficulté : 10760.71 | Coût : 6818.08 | Durée : 37.88 h
#   P008012 | Difficulté : 327.68 | Coût : 1402.16 | Durée : 5.61 h
#   P008013 | Difficulté : 12878.30 | Coût : 7458.84 | Durée : 41.44 h
#   P000476 | Difficulté : 3128.62 | Coût : 3676.36 | Durée : 20.42 h
#   P008016 | Difficulté : 12130.51 | Coût : 7239.05 | Durée : 40.22 h
#   P000470 | Difficulté : 275.69 | Coût : 1286.12 | Durée : 5.14 h
#   P008019 | Difficulté : 2169.36 | Coût : 3124.44 | Durée : 16.66 h
#   P000464 | Difficulté : 4426.40 | Coût : 4372.88 | Durée : 24.29 h
#   P000462 | Difficulté : 2559.63 | Coût : 3325.30 | Durée : 18.47 h
#   P008017 | Difficulté : 760.51 | Coût : 2136.13 | Durée : 8.54 h
#   P008018 | Difficulté : 9063.11 | Coût : 7374.19 | Durée : 29.50 h
#   P007616 | Difficulté : 2393.50 | Coût : 3789.59 | Durée : 15.16 h
#   P005317 | Difficulté : 7142.17 | Coût : 5975.86 | Durée : 23.90 h
#   P007999 | Difficulté : 88681.23 | Coût : 21057.21 | Durée : 84.23 h
#   P007485 | Difficulté : 4787.43 | Coût : 4237.08 | Durée : 22.60 h
#   P005500 | Difficulté : 21589.14 | Coût : 6571.02 | Durée : 26.28 h
#   P007990 | Difficulté : 43724.63 | Coût : 9351.43 | Durée : 37.41 h
#   P001391 | Difficulté : 32797.98 | Coût : 6872.34 | Durée : 38.18 h
#   P007689 | Difficulté : 3255.99 | Coût : 2551.86 | Durée : 10.21 h
#   P006106 | Difficulté : 41518.40 | Coût : 6443.48 | Durée : 25.77 h
#   P002717 | Difficulté : 54045.68 | Coût : 6238.02 | Durée : 34.66 h
#   P007565 | Difficulté : 10447.19 | Coût : 3232.21 | Durée : 12.93 h
#
#  Phase 2 | Infra à remplacer : 103
#   P005100 | Difficulté : 4898.07 | Coût : 3129.88 | Durée : 12.52 h
#   P000732 | Difficulté : 14545.29 | Coût : 5393.57 | Durée : 21.57 h
#   P008001 | Difficulté : 12009.44 | Coût : 4900.91 | Durée : 19.60 h
#   P000719 | Difficulté : 14306.33 | Coût : 5349.08 | Durée : 21.40 h
#   P008003 | Difficulté : 36102.86 | Coût : 8497.39 | Durée : 33.99 h
#   P008004 | Difficulté : 10245.95 | Coût : 3841.12 | Durée : 21.34 h
#   P000494 | Difficulté : 2928.28 | Coût : 2420.04 | Durée : 9.68 h
#   P000744 | Difficulté : 3868.66 | Coût : 2781.60 | Durée : 11.13 h
#   P007686 | Difficulté : 7201.95 | Coût : 3795.25 | Durée : 15.18 h
#   P005100 | Difficulté : 2449.03 | Coût : 3129.88 | Durée : 12.52 h
#   P000732 | Difficulté : 7272.65 | Coût : 5393.57 | Durée : 21.57 h
#   P008001 | Difficulté : 6004.72 | Coût : 4900.91 | Durée : 19.60 h
#   P000719 | Difficulté : 7153.16 | Coût : 5349.08 | Durée : 21.40 h
#   P008003 | Difficulté : 18051.43 | Coût : 8497.39 | Durée : 33.99 h
#   P008004 | Difficulté : 5122.97 | Coût : 3841.12 | Durée : 21.34 h
#   P000494 | Difficulté : 1464.14 | Coût : 2420.04 | Durée : 9.68 h
#   P008010 | Difficulté : 16141.06 | Coût : 6818.08 | Durée : 37.88 h
#   P008012 | Difficulté : 491.52 | Coût : 1402.16 | Durée : 5.61 h
#   P008013 | Difficulté : 19317.45 | Coût : 7458.84 | Durée : 41.44 h
#   P000476 | Difficulté : 4692.93 | Coût : 3676.36 | Durée : 20.42 h
#   P008016 | Difficulté : 18195.77 | Coût : 7239.05 | Durée : 40.22 h
#   P008020 | Difficulté : 8633.06 | Coût : 5876.42 | Durée : 23.51 h
#   P007567 | Difficulté : 1383.86 | Coût : 2352.75 | Durée : 9.41 h
#   P005100 | Difficulté : 2449.03 | Coût : 3129.88 | Durée : 12.52 h
#   P000732 | Difficulté : 7272.65 | Coût : 5393.57 | Durée : 21.57 h
#   P008001 | Difficulté : 6004.72 | Coût : 4900.91 | Durée : 19.60 h
#   P000719 | Difficulté : 7153.16 | Coût : 5349.08 | Durée : 21.40 h
#   P008003 | Difficulté : 18051.43 | Coût : 8497.39 | Durée : 33.99 h
#   P008004 | Difficulté : 5122.97 | Coût : 3841.12 | Durée : 21.34 h
#   P000494 | Difficulté : 1464.14 | Coût : 2420.04 | Durée : 9.68 h
#   P008010 | Difficulté : 16141.06 | Coût : 6818.08 | Durée : 37.88 h
#   P008012 | Difficulté : 491.52 | Coût : 1402.16 | Durée : 5.61 h
#   P008013 | Difficulté : 19317.45 | Coût : 7458.84 | Durée : 41.44 h
#   P000476 | Difficulté : 4692.93 | Coût : 3676.36 | Durée : 20.42 h
#   P008016 | Difficulté : 18195.77 | Coût : 7239.05 | Durée : 40.22 h
#   P000470 | Difficulté : 413.53 | Coût : 1286.12 | Durée : 5.14 h
#   P008019 | Difficulté : 3254.04 | Coût : 3124.44 | Durée : 16.66 h
#   P000464 | Difficulté : 6639.60 | Coût : 4372.88 | Durée : 24.29 h
#   P000629 | Difficulté : 1764.69 | Coût : 2656.83 | Durée : 10.63 h
#   P007544 | Difficulté : 695.68 | Coût : 1668.15 | Durée : 6.67 h
#   P005100 | Difficulté : 4898.07 | Coût : 3129.88 | Durée : 12.52 h
#   P000732 | Difficulté : 14545.29 | Coût : 5393.57 | Durée : 21.57 h
#   P008001 | Difficulté : 12009.44 | Coût : 4900.91 | Durée : 19.60 h
#   P000719 | Difficulté : 14306.33 | Coût : 5349.08 | Durée : 21.40 h
#   P008003 | Difficulté : 36102.86 | Coût : 8497.39 | Durée : 33.99 h
#   P008004 | Difficulté : 10245.95 | Coût : 3841.12 | Durée : 21.34 h
#   P000494 | Difficulté : 2928.28 | Coût : 2420.04 | Durée : 9.68 h
#   P000744 | Difficulté : 3868.66 | Coût : 2781.60 | Durée : 11.13 h
#   P007458 | Difficulté : 26658.93 | Coût : 6195.87 | Durée : 34.42 h
#   P006950 | Difficulté : 3496.77 | Coût : 4487.92 | Durée : 24.93 h
#   P008033 | Difficulté : 131132.50 | Coût : 27483.14 | Durée : 152.68 h
#   P004282 | Difficulté : 1182.52 | Coût : 3075.74 | Durée : 12.30 h
#   P004284 | Difficulté : 926.93 | Coût : 2723.13 | Durée : 10.89 h
#   P007609 | Difficulté : 1899.36 | Coût : 3898.06 | Durée : 15.59 h
#   P005500 | Difficulté : 43178.27 | Coût : 6571.02 | Durée : 26.28 h
#   P007990 | Difficulté : 87449.25 | Coût : 9351.43 | Durée : 37.41 h
#   P007447 | Difficulté : 9108.03 | Coût : 2560.82 | Durée : 14.23 h
#   P005100 | Difficulté : 3265.38 | Coût : 3129.88 | Durée : 12.52 h
#   P000732 | Difficulté : 9696.86 | Coût : 5393.57 | Durée : 21.57 h
#   P008001 | Difficulté : 8006.30 | Coût : 4900.91 | Durée : 19.60 h
#   P000719 | Difficulté : 9537.55 | Coût : 5349.08 | Durée : 21.40 h
#   P008003 | Difficulté : 24068.57 | Coût : 8497.39 | Durée : 33.99 h
#   P008004 | Difficulté : 6830.63 | Coût : 3841.12 | Durée : 21.34 h
#   P000494 | Difficulté : 1952.19 | Coût : 2420.04 | Durée : 9.68 h
#   P008010 | Difficulté : 21521.41 | Coût : 6818.08 | Durée : 37.88 h
#   P008012 | Difficulté : 655.35 | Coût : 1402.16 | Durée : 5.61 h
#   P008013 | Difficulté : 25756.60 | Coût : 7458.84 | Durée : 41.44 h
#   P000476 | Difficulté : 6257.23 | Coût : 3676.36 | Durée : 20.42 h
#   P008016 | Difficulté : 24261.02 | Coût : 7239.05 | Durée : 40.22 h
#   P000470 | Difficulté : 551.37 | Coût : 1286.12 | Durée : 5.14 h
#   P008019 | Difficulté : 4338.72 | Coût : 3124.44 | Durée : 16.66 h
#   P000633 | Difficulté : 2246.54 | Coût : 2596.08 | Durée : 10.38 h
#   P007677 | Difficulté : 4747.36 | Coût : 3202.23 | Durée : 17.79 h
#   P005500 | Difficulté : 14392.76 | Coût : 6571.02 | Durée : 26.28 h
#   P007991 | Difficulté : 21143.45 | Coût : 6757.95 | Durée : 37.54 h
#   P007998 | Difficulté : 114476.08 | Coût : 18531.82 | Durée : 74.13 h
#   P007554 | Difficulté : 28559.57 | Coût : 7854.21 | Durée : 43.63 h
#   P005100 | Difficulté : 4898.07 | Coût : 3129.88 | Durée : 12.52 h
#   P000732 | Difficulté : 14545.29 | Coût : 5393.57 | Durée : 21.57 h
#   P008001 | Difficulté : 12009.44 | Coût : 4900.91 | Durée : 19.60 h
#   P000719 | Difficulté : 14306.33 | Coût : 5349.08 | Durée : 21.40 h
#   P008005 | Difficulté : 8825.15 | Coût : 4201.23 | Durée : 16.80 h
#   P008009 | Difficulté : 79417.24 | Coût : 12602.96 | Durée : 50.41 h
#   P000604 | Difficulté : 9310.69 | Coût : 3737.12 | Durée : 19.93 h
#   P007580 | Difficulté : 39984.28 | Coût : 7587.97 | Durée : 42.16 h
#   P005500 | Difficulté : 7196.38 | Coût : 6571.02 | Durée : 26.28 h
#   P007991 | Difficulté : 10571.73 | Coût : 6757.95 | Durée : 37.54 h
#   P007997 | Difficulté : 170210.89 | Coût : 27116.62 | Durée : 150.65 h
#   P007572 | Difficulté : 1319.30 | Coût : 2813.50 | Durée : 11.25 h
#   P005500 | Difficulté : 7196.38 | Coût : 6571.02 | Durée : 26.28 h
#   P007991 | Difficulté : 10571.73 | Coût : 6757.95 | Durée : 37.54 h
#   P007997 | Difficulté : 170210.89 | Coût : 27116.62 | Durée : 150.65 h
#   P007476 | Difficulté : 4554.38 | Coût : 4435.64 | Durée : 24.64 h
#   P006712 | Difficulté : 88683.81 | Coût : 11300.65 | Durée : 62.78 h
#   P003802 | Difficulté : 19535.01 | Coût : 6250.60 | Durée : 25.00 h
#   P003870 | Difficulté : 5255.51 | Coût : 3242.07 | Durée : 12.97 h
#   P003881 | Difficulté : 3759.69 | Coût : 2742.15 | Durée : 10.97 h
#   P003903 | Difficulté : 14885.31 | Coût : 5456.25 | Durée : 21.82 h
#   P007478 | Difficulté : 62427.21 | Coût : 9676.82 | Durée : 51.61 h
#   P005500 | Difficulté : 43178.27 | Coût : 6571.02 | Durée : 26.28 h
#   P007990 | Difficulté : 87449.25 | Coût : 9351.43 | Durée : 37.41 h
#   P001391 | Difficulté : 65595.97 | Coût : 6872.34 | Durée : 38.18 h
#   P007752 | Difficulté : 2446.65 | Coût : 1564.18 | Durée : 6.26 h
#
#  Phase 3 | Infra à remplacer : 105
#   P005100 | Difficulté : 4898.07 | Coût : 3129.88 | Durée : 12.52 h
#   P000732 | Difficulté : 14545.29 | Coût : 5393.57 | Durée : 21.57 h
#   P008001 | Difficulté : 12009.44 | Coût : 4900.91 | Durée : 19.60 h
#   P000719 | Difficulté : 14306.33 | Coût : 5349.08 | Durée : 21.40 h
#   P008003 | Difficulté : 36102.86 | Coût : 8497.39 | Durée : 33.99 h
#   P008004 | Difficulté : 10245.95 | Coût : 3841.12 | Durée : 21.34 h
#   P000494 | Difficulté : 2928.28 | Coût : 2420.04 | Durée : 9.68 h
#   P008010 | Difficulté : 32282.12 | Coût : 6818.08 | Durée : 37.88 h
#   P008014 | Difficulté : 71728.26 | Coût : 10372.67 | Durée : 55.32 h
#   P007695 | Difficulté : 10815.85 | Coût : 3946.49 | Durée : 21.92 h
#   P005100 | Difficulté : 2449.03 | Coût : 3129.88 | Durée : 12.52 h
#   P000732 | Difficulté : 7272.65 | Coût : 5393.57 | Durée : 21.57 h
#   P008001 | Difficulté : 6004.72 | Coût : 4900.91 | Durée : 19.60 h
#   P000719 | Difficulté : 7153.16 | Coût : 5349.08 | Durée : 21.40 h
#   P008005 | Difficulté : 4412.57 | Coût : 4201.23 | Durée : 16.80 h
#   P000723 | Difficulté : 10824.00 | Coût : 6579.97 | Durée : 26.32 h
#   P008008 | Difficulté : 72741.36 | Coût : 17057.71 | Durée : 68.23 h
#   P008022 | Difficulté : 75852.16 | Coût : 17418.63 | Durée : 69.67 h
#   P008026 | Difficulté : 27081.98 | Coût : 9013.65 | Durée : 48.07 h
#   P007607 | Difficulté : 3648.64 | Coût : 3820.28 | Durée : 15.28 h
#   P005100 | Difficulté : 4898.07 | Coût : 3129.88 | Durée : 12.52 h
#   P000732 | Difficulté : 14545.29 | Coût : 5393.57 | Durée : 21.57 h
#   P008001 | Difficulté : 12009.44 | Coût : 4900.91 | Durée : 19.60 h
#   P000719 | Difficulté : 14306.33 | Coût : 5349.08 | Durée : 21.40 h
#   P008003 | Difficulté : 36102.86 | Coût : 8497.39 | Durée : 33.99 h
#   P008004 | Difficulté : 10245.95 | Coût : 3841.12 | Durée : 21.34 h
#   P000494 | Difficulté : 2928.28 | Coût : 2420.04 | Durée : 9.68 h
#   P008010 | Difficulté : 32282.12 | Coût : 6818.08 | Durée : 37.88 h
#   P008012 | Difficulté : 983.03 | Coût : 1402.16 | Durée : 5.61 h
#   P008013 | Difficulté : 38634.89 | Coût : 7458.84 | Durée : 41.44 h
#   P000476 | Difficulté : 9385.85 | Coût : 3676.36 | Durée : 20.42 h
#   P008016 | Difficulté : 36391.53 | Coût : 7239.05 | Durée : 40.22 h
#   P000470 | Difficulté : 827.06 | Coût : 1286.12 | Durée : 5.14 h
#   P000635 | Difficulté : 3336.52 | Coût : 2583.22 | Durée : 10.33 h
#   P007584 | Difficulté : 1187.06 | Coût : 1540.82 | Durée : 6.16 h
#   P005100 | Difficulté : 9796.14 | Coût : 3129.88 | Durée : 12.52 h
#   P000732 | Difficulté : 29090.59 | Coût : 5393.57 | Durée : 21.57 h
#   P008001 | Difficulté : 24018.89 | Coût : 4900.91 | Durée : 19.60 h
#   P000719 | Difficulté : 28612.65 | Coût : 5349.08 | Durée : 21.40 h
#   P008003 | Difficulté : 72205.72 | Coût : 8497.39 | Durée : 33.99 h
#   P008004 | Difficulté : 20491.90 | Coût : 3841.12 | Durée : 21.34 h
#   P000494 | Difficulté : 5856.57 | Coût : 2420.04 | Durée : 9.68 h
#   P000750 | Difficulté : 33049.47 | Coût : 4878.08 | Durée : 27.10 h
#   P007727 | Difficulté : 9990.06 | Coût : 3160.71 | Durée : 12.64 h
#   P005100 | Difficulté : 4898.07 | Coût : 3129.88 | Durée : 12.52 h
#   P000732 | Difficulté : 14545.29 | Coût : 5393.57 | Durée : 21.57 h
#   P008001 | Difficulté : 12009.44 | Coût : 4900.91 | Durée : 19.60 h
#   P000719 | Difficulté : 14306.33 | Coût : 5349.08 | Durée : 21.40 h
#   P008003 | Difficulté : 36102.86 | Coût : 8497.39 | Durée : 33.99 h
#   P008004 | Difficulté : 10245.95 | Coût : 3841.12 | Durée : 21.34 h
#   P000494 | Difficulté : 2928.28 | Coût : 2420.04 | Durée : 9.68 h
#   P008010 | Difficulté : 32282.12 | Coût : 6818.08 | Durée : 37.88 h
#   P008012 | Difficulté : 983.03 | Coût : 1402.16 | Durée : 5.61 h
#   P008013 | Difficulté : 38634.89 | Coût : 7458.84 | Durée : 41.44 h
#   P000476 | Difficulté : 9385.85 | Coût : 3676.36 | Durée : 20.42 h
#   P008016 | Difficulté : 36391.53 | Coût : 7239.05 | Durée : 40.22 h
#   P000470 | Difficulté : 827.06 | Coût : 1286.12 | Durée : 5.14 h
#   P008019 | Difficulté : 6508.07 | Coût : 3124.44 | Durée : 16.66 h
#   P000464 | Difficulté : 13279.21 | Coût : 4372.88 | Durée : 24.29 h
#   P000462 | Difficulté : 7678.90 | Coût : 3325.30 | Durée : 18.47 h
#   P008017 | Difficulté : 2281.53 | Coût : 2136.13 | Durée : 8.54 h
#   P000621 | Difficulté : 4583.10 | Coût : 3027.57 | Durée : 12.11 h
#   P007533 | Difficulté : 3042.51 | Coût : 2136.30 | Durée : 11.39 h
#   P005100 | Difficulté : 4898.07 | Coût : 3129.88 | Durée : 12.52 h
#   P000732 | Difficulté : 14545.29 | Coût : 5393.57 | Durée : 21.57 h
#   P008001 | Difficulté : 12009.44 | Coût : 4900.91 | Durée : 19.60 h
#   P000719 | Difficulté : 14306.33 | Coût : 5349.08 | Durée : 21.40 h
#   P008003 | Difficulté : 36102.86 | Coût : 8497.39 | Durée : 33.99 h
#   P008004 | Difficulté : 10245.95 | Coût : 3841.12 | Durée : 21.34 h
#   P000494 | Difficulté : 2928.28 | Coût : 2420.04 | Durée : 9.68 h
#   P008010 | Difficulté : 32282.12 | Coût : 6818.08 | Durée : 37.88 h
#   P008012 | Difficulté : 983.03 | Coût : 1402.16 | Durée : 5.61 h
#   P008013 | Difficulté : 38634.89 | Coût : 7458.84 | Durée : 41.44 h
#   P000476 | Difficulté : 9385.85 | Coût : 3676.36 | Durée : 20.42 h
#   P008016 | Difficulté : 36391.53 | Coût : 7239.05 | Durée : 40.22 h
#   P000470 | Difficulté : 827.06 | Coût : 1286.12 | Durée : 5.14 h
#   P008019 | Difficulté : 6508.07 | Coût : 3124.44 | Durée : 16.66 h
#   P000464 | Difficulté : 13279.21 | Coût : 4372.88 | Durée : 24.29 h
#   P000462 | Difficulté : 7678.90 | Coût : 3325.30 | Durée : 18.47 h
#   P000627 | Difficulté : 13553.53 | Coût : 4417.81 | Durée : 24.54 h
#   P007645 | Difficulté : 1151.57 | Coût : 1517.61 | Durée : 6.07 h
#   P006950 | Difficulté : 5594.83 | Coût : 4487.92 | Durée : 24.93 h
#   P008033 | Difficulté : 209812.00 | Coût : 27483.14 | Durée : 152.68 h
#   P004271 | Difficulté : 9834.84 | Coût : 5950.24 | Durée : 33.06 h
#   P004269 | Difficulté : 3226.02 | Coût : 4016.23 | Durée : 16.06 h
#   P004261 | Difficulté : 9816.58 | Coût : 6067.30 | Durée : 32.36 h
#   P007610 | Difficulté : 17697.94 | Coût : 7982.02 | Durée : 44.34 h
#   P005100 | Difficulté : 3265.38 | Coût : 3129.88 | Durée : 12.52 h
#   P000732 | Difficulté : 9696.86 | Coût : 5393.57 | Durée : 21.57 h
#   P008001 | Difficulté : 8006.30 | Coût : 4900.91 | Durée : 19.60 h
#   P000719 | Difficulté : 9537.55 | Coût : 5349.08 | Durée : 21.40 h
#   P008005 | Difficulté : 5883.43 | Coût : 4201.23 | Durée : 16.80 h
#   P000723 | Difficulté : 14432.01 | Coût : 6579.97 | Durée : 26.32 h
#   P008008 | Difficulté : 96988.47 | Coût : 17057.71 | Durée : 68.23 h
#   P008022 | Difficulté : 101136.21 | Coût : 17418.63 | Durée : 69.67 h
#   P007595 | Difficulté : 25041.09 | Coût : 7506.16 | Durée : 40.03 h
#   P007113 | Difficulté : 37170.41 | Coût : 6096.75 | Durée : 24.39 h
#   P007984 | Difficulté : 225864.80 | Coût : 15028.80 | Durée : 60.12 h
#   P007823 | Difficulté : 37762.76 | Coût : 6145.14 | Durée : 24.58 h
#   P006709 | Difficulté : 15010.75 | Coût : 6710.61 | Durée : 26.84 h
#   P008025 | Difficulté : 9661.28 | Coût : 5383.67 | Durée : 21.53 h
#   P003849 | Difficulté : 7431.76 | Coût : 4006.57 | Durée : 22.26 h
#   P008029 | Difficulté : 259748.39 | Coût : 24175.07 | Durée : 128.93 h
#   P003934 | Difficulté : 3635.10 | Coût : 3302.32 | Durée : 13.21 h
#   P007552 | Difficulté : 26034.89 | Coût : 7499.02 | Durée : 41.66 h
#
#  Phase 4 | Infra à remplacer : 100
#   P005100 | Difficulté : 9796.14 | Coût : 3129.88 | Durée : 12.52 h
#   P000732 | Difficulté : 29090.59 | Coût : 5393.57 | Durée : 21.57 h
#   P008001 | Difficulté : 24018.89 | Coût : 4900.91 | Durée : 19.60 h
#   P000719 | Difficulté : 28612.65 | Coût : 5349.08 | Durée : 21.40 h
#   P008003 | Difficulté : 72205.72 | Coût : 8497.39 | Durée : 33.99 h
#   P008004 | Difficulté : 20491.90 | Coût : 3841.12 | Durée : 21.34 h
#   P000494 | Difficulté : 5856.57 | Coût : 2420.04 | Durée : 9.68 h
#   P008010 | Difficulté : 64564.23 | Coût : 6818.08 | Durée : 37.88 h
#   P008012 | Difficulté : 1966.06 | Coût : 1402.16 | Durée : 5.61 h
#   P008011 | Difficulté : 76214.48 | Coût : 7560.48 | Durée : 40.32 h
#   P007731 | Difficulté : 16242.34 | Coût : 3419.72 | Durée : 19.00 h
#   P006709 | Difficulté : 15010.75 | Coût : 6710.61 | Durée : 26.84 h
#   P008025 | Difficulté : 9661.28 | Coût : 5383.67 | Durée : 21.53 h
#   P003849 | Difficulté : 7431.76 | Coût : 4006.57 | Durée : 22.26 h
#   P008029 | Difficulté : 259748.39 | Coût : 24175.07 | Durée : 128.93 h
#   P008030 | Difficulté : 25661.02 | Coût : 7598.51 | Durée : 40.53 h
#   P007715 | Difficulté : 35746.67 | Coût : 8968.28 | Durée : 47.83 h
#   P005100 | Difficulté : 9796.14 | Coût : 3129.88 | Durée : 12.52 h
#   P000732 | Difficulté : 29090.59 | Coût : 5393.57 | Durée : 21.57 h
#   P008001 | Difficulté : 24018.89 | Coût : 4900.91 | Durée : 19.60 h
#   P000719 | Difficulté : 28612.65 | Coût : 5349.08 | Durée : 21.40 h
#   P008003 | Difficulté : 72205.72 | Coût : 8497.39 | Durée : 33.99 h
#   P008004 | Difficulté : 20491.90 | Coût : 3841.12 | Durée : 21.34 h
#   P000494 | Difficulté : 5856.57 | Coût : 2420.04 | Durée : 9.68 h
#   P008010 | Difficulté : 64564.23 | Coût : 6818.08 | Durée : 37.88 h
#   P008012 | Difficulté : 1966.06 | Coût : 1402.16 | Durée : 5.61 h
#   P008013 | Difficulté : 77269.79 | Coût : 7458.84 | Durée : 41.44 h
#   P000476 | Difficulté : 18771.70 | Coût : 3676.36 | Durée : 20.42 h
#   P000717 | Difficulté : 6412.84 | Coût : 2532.36 | Durée : 10.13 h
#   P007618 | Difficulté : 3970.31 | Coût : 1992.56 | Durée : 7.97 h
#   P006950 | Difficulté : 9324.72 | Coût : 4487.92 | Durée : 24.93 h
#   P008033 | Difficulté : 349686.67 | Coût : 27483.14 | Durée : 152.68 h
#   P004282 | Difficulté : 3153.39 | Coût : 3075.74 | Durée : 12.30 h
#   P004284 | Difficulté : 2471.81 | Coût : 2723.13 | Durée : 10.89 h
#   P007564 | Difficulté : 4238.42 | Coût : 3565.84 | Durée : 14.26 h
#   P006950 | Difficulté : 9324.72 | Coût : 4487.92 | Durée : 24.93 h
#   P008033 | Difficulté : 349686.67 | Coût : 27483.14 | Durée : 152.68 h
#   P004271 | Difficulté : 16391.39 | Coût : 5950.24 | Durée : 33.06 h
#   P004269 | Difficulté : 5376.70 | Coût : 4016.23 | Durée : 16.06 h
#   P007507 | Difficulté : 25493.62 | Coût : 7420.66 | Durée : 41.23 h
#   P005100 | Difficulté : 9796.14 | Coût : 3129.88 | Durée : 12.52 h
#   P000732 | Difficulté : 29090.59 | Coût : 5393.57 | Durée : 21.57 h
#   P008001 | Difficulté : 24018.89 | Coût : 4900.91 | Durée : 19.60 h
#   P000719 | Difficulté : 28612.65 | Coût : 5349.08 | Durée : 21.40 h
#   P005193 | Difficulté : 236241.83 | Coût : 13042.01 | Durée : 72.46 h
#   P007992 | Difficulté : 121647.38 | Coût : 9358.75 | Durée : 51.99 h
#   P007648 | Difficulté : 2886.55 | Coût : 1698.98 | Durée : 6.80 h
#   P005100 | Difficulté : 9796.14 | Coût : 3129.88 | Durée : 12.52 h
#   P000732 | Difficulté : 29090.59 | Coût : 5393.57 | Durée : 21.57 h
#   P008001 | Difficulté : 24018.89 | Coût : 4900.91 | Durée : 19.60 h
#   P000719 | Difficulté : 28612.65 | Coût : 5349.08 | Durée : 21.40 h
#   P008005 | Difficulté : 17650.30 | Coût : 4201.23 | Durée : 16.80 h
#   P000723 | Difficulté : 43296.02 | Coût : 6579.97 | Durée : 26.32 h
#   P008008 | Difficulté : 290965.42 | Coût : 17057.71 | Durée : 68.23 h
#   P008021 | Difficulté : 55589.79 | Coût : 7455.86 | Durée : 29.82 h
#   P007785 | Difficulté : 16551.70 | Coût : 4068.38 | Durée : 16.27 h
#   P005000 | Difficulté : 5545.27 | Coût : 2039.35 | Durée : 10.88 h
#   P008027 | Difficulté : 470744.24 | Coût : 18410.21 | Durée : 102.28 h
#   P007530 | Difficulté : 40550.98 | Coût : 6367.97 | Durée : 25.47 h
#   P006950 | Difficulté : 13987.08 | Coût : 4487.92 | Durée : 24.93 h
#   P008033 | Difficulté : 524530.01 | Coût : 27483.14 | Durée : 152.68 h
#   P004282 | Difficulté : 4730.09 | Coût : 3075.74 | Durée : 12.30 h
#   P007528 | Difficulté : 14471.32 | Coût : 5379.84 | Durée : 21.52 h
#   P006950 | Difficulté : 13987.08 | Coût : 4487.92 | Durée : 24.93 h
#   P008033 | Difficulté : 524530.01 | Coût : 27483.14 | Durée : 152.68 h
#   P004271 | Difficulté : 24587.09 | Coût : 5950.24 | Durée : 33.06 h
#   P004269 | Difficulté : 8065.05 | Coût : 4016.23 | Durée : 16.06 h
#   P004261 | Difficulté : 24541.45 | Coût : 6067.30 | Durée : 32.36 h
#   P004257 | Difficulté : 14016.75 | Coût : 4585.32 | Durée : 24.46 h
#   P004251 | Difficulté : 4256.07 | Coût : 2917.56 | Durée : 11.67 h
#   P007766 | Difficulté : 45084.70 | Coût : 8223.57 | Durée : 43.86 h
#   P005100 | Difficulté : 4898.07 | Coût : 3129.88 | Durée : 12.52 h
#   P000732 | Difficulté : 14545.29 | Coût : 5393.57 | Durée : 21.57 h
#   P008001 | Difficulté : 12009.44 | Coût : 4900.91 | Durée : 19.60 h
#   P000719 | Difficulté : 14306.33 | Coût : 5349.08 | Durée : 21.40 h
#   P008005 | Difficulté : 8825.15 | Coût : 4201.23 | Durée : 16.80 h
#   P008009 | Difficulté : 79417.24 | Coût : 12602.96 | Durée : 50.41 h
#   P008015 | Difficulté : 673824.43 | Coût : 31149.75 | Durée : 173.05 h
#   P008023 | Difficulté : 47711.48 | Coût : 8459.74 | Durée : 45.12 h
#   P007562 | Difficulté : 65013.53 | Coût : 9675.72 | Durée : 53.75 h
#   P005100 | Difficulté : 4898.07 | Coût : 3129.88 | Durée : 12.52 h
#   P000732 | Difficulté : 14545.29 | Coût : 5393.57 | Durée : 21.57 h
#   P008001 | Difficulté : 12009.44 | Coût : 4900.91 | Durée : 19.60 h
#   P000719 | Difficulté : 14306.33 | Coût : 5349.08 | Durée : 21.40 h
#   P008005 | Difficulté : 8825.15 | Coût : 4201.23 | Durée : 16.80 h
#   P008009 | Difficulté : 79417.24 | Coût : 12602.96 | Durée : 50.41 h
#   P008015 | Difficulté : 673824.43 | Coût : 31149.75 | Durée : 173.05 h
#   P008024 | Difficulté : 188582.89 | Coût : 16479.06 | Durée : 91.55 h
#   P007566 | Difficulté : 24556.53 | Coût : 5946.55 | Durée : 33.04 h
#   P006950 | Difficulté : 27974.15 | Coût : 4487.92 | Durée : 24.93 h
#   P008033 | Difficulté : 1049060.02 | Coût : 27483.14 | Durée : 152.68 h
#   P004271 | Difficulté : 49174.18 | Coût : 5950.24 | Durée : 33.06 h
#   P007529 | Difficulté : 38918.78 | Coût : 6238.49 | Durée : 24.95 h
#   P006950 | Difficulté : 27974.15 | Coût : 4487.92 | Durée : 24.93 h
#   P008033 | Difficulté : 1049060.02 | Coût : 27483.14 | Durée : 152.68 h
#   P004271 | Difficulté : 49174.18 | Coût : 5950.24 | Durée : 33.06 h
#   P004269 | Difficulté : 16130.09 | Coût : 4016.23 | Durée : 16.06 h
#   P004261 | Difficulté : 49082.90 | Coût : 6067.30 | Durée : 32.36 h
#   P004257 | Difficulté : 28033.50 | Coût : 4585.32 | Durée : 24.46 h
#   P007768 | Difficulté : 21760.19 | Coût : 4664.78 | Durée : 18.66 h
# {'E000001': 0, 'E000002': 0, 'E000003': 300797.9752828375, 'E000004': 0, 'E000005': 0, 'E000006': 0, 'E000007': 0, 'E000008': 0, 'E000009': 0, 'E000010': 0, 'E000011': 0, 'E000012': 0, 'E000013': 0, 'E000014': 0, 'E000015': 0, 'E000016': 0, 'E000017': 0, 'E000018': 0, 'E000019': 0, 'E000020': 0, 'E000021': 0, 'E000022': 0, 'E000023': 0, 'E000024': 0, 'E000025': 0, 'E000026': 0, 'E000027': 0, 'E000028': 0, 'E000029': 0, 'E000030': 0, 'E000031': 0, 'E000032': 0, 'E000033': 0, 'E000034': 0, 'E000035': 0, 'E000036': 0, 'E000037': 0, 'E000038': 0, 'E000039': 0, 'E000040': 0, 'E000041': 0, 'E000042': 0, 'E000043': 0, 'E000044': 0, 'E000045': 0, 'E000046': 0, 'E000047': 0, 'E000048': 0, 'E000049': 0, 'E000050': 0, 'E000051': 0, 'E000052': 0, 'E000053': 0, 'E000054': 0, 'E000055': 0, 'E000056': 0, 'E000057': 0, 'E000058': 0, 'E000059': 0, 'E000060': 0, 'E000061': 0, 'E000062': 0, 'E000063': 0, 'E000064': 0, 'E000065': 0, 'E000066': 0, 'E000067': 64706.564909602595, 'E000068': 0, 'E000069': 0, 'E000070': 0, 'E000071': 0, 'E000072': 0, 'E000073': 0, 'E000074': 0, 'E000075': 0, 'E000076': 0, 'E000077': 0, 'E000078': 0, 'E000079': 0, 'E000080': 0, 'E000081': 0, 'E000082': 0, 'E000083': 0, 'E000084': 0, 'E000085': 139735.5516492084, 'E000086': 0, 'E000087': 0, 'E000088': 0, 'E000089': 0, 'E000090': 0, 'E000091': 0, 'E000092': 0, 'E000093': 0, 'E000094': 0, 'E000095': 0, 'E000096': 0, 'E000097': 0, 'E000098': 13919.740407297693, 'E000099': 0, 'E000100': 0, 'E000101': 0, 'E000102': 0, 'E000103': 0, 'E000104': 0, 'E000105': 0, 'E000106': 198670.13486117293, 'E000107': 101367.73012604294, 'E000108': 192533.3753426667, 'E000109': 189298.2963147744, 'E000110': 178571.86368020956, 'E000111': 15572.694424065847, 'E000112': 9594.92198834266, 'E000113': 0, 'E000114': 0, 'E000115': 0, 'E000116': 0, 'E000117': 0, 'E000118': 0, 'E000119': 0, 'E000120': 0, 'E000121': 0, 'E000122': 0, 'E000123': 0, 'E000124': 0, 'E000125': 0, 'E000126': 0, 'E000127': 11252.819907104196, 'E000128': 16144.270613664045, 'E000129': 100610.83286346686, 'E000130': 0, 'E000131': 0, 'E000132': 0, 'E000133': 0, 'E000134': 0, 'E000135': 0, 'E000136': 0, 'E000137': 0, 'E000138': 0, 'E000139': 0, 'E000140': 0, 'E000141': 0, 'E000142': 0, 'E000143': 0, 'E000144': 54289.993217512456, 'E000145': 87245.32036522566, 'E000146': 58079.07057671544, 'E000147': 0, 'E000148': 0, 'E000149': 0, 'E000150': 0, 'E000151': 0, 'E000152': 0, 'E000153': 0, 'E000154': 0, 'E000155': 0, 'E000156': 0, 'E000157': 0, 'E000158': 0, 'E000159': 0, 'E000160': 23386.926041536877, 'E000161': 183296.49098499632, 'E000162': 0, 'E000163': 0, 'E000164': 0, 'E000165': 0, 'E000166': 0, 'E000167': 0, 'E000168': 0, 'E000169': 0, 'E000170': 0, 'E000171': 0, 'E000172': 0, 'E000173': 0, 'E000174': 515571.5038171851, 'E000175': 273987.29685203964, 'E000176': 920550.967778674, 'E000177': 1020965.3697905641, 'E000178': 233111.98862000444, 'E000179': 0, 'E000180': 0, 'E000181': 0, 'E000182': 0, 'E000183': 516840.49215909734, 'E000184': 71431.1422433184, 'E000185': 106011.27054531974, 'E000186': 0, 'E000187': 0, 'E000188': 74100.87980114757, 'E000189': 0, 'E000190': 0, 'E000191': 0, 'E000192': 0, 'E000193': 217440.28124983484, 'E000194': 18303.653701462437, 'E000195': 22879.56712682805, 'E000196': 30506.089502437397, 'E000197': 51624.46107946079, 'E000198': 209862.44684789586, 'E000199': 0, 'E000200': 0, 'E000201': 0, 'E000202': 0, 'E000203': 0, 'E000204': 0, 'E000205': 0, 'E000206': 0, 'E000207': 0, 'E000208': 0, 'E000209': 0, 'E000210': 0, 'E000211': 0, 'E000212': 0, 'E000213': 0, 'E000214': 0, 'E000215': 0, 'E000216': 0, 'E000217': 0, 'E000218': 0, 'E000219': 0, 'E000220': 0, 'E000221': 0, 'E000222': 17960.273148330492, 'E000223': 0, 'E000224': 0, 'E000225': 18303.653701462437, 'E000226': 125563.81692954368, 'E000227': 106106.84057315312, 'E000228': 41621.68542905747, 'E000229': 349059.5696133805, 'E000230': 0, 'E000231': 0, 'E000232': 0, 'E000233': 0, 'E000234': 0, 'E000235': 0, 'E000236': 0, 'E000237': 0, 'E000238': 0, 'E000 ...
# {'P007111': 21325.212842019486, 'P007983': 81288.86523300996, 'P000308': 430875.59411812975, 'P007819': 113410.59352686006, 'P007240': 9927.421341178851, 'P007113': 37170.413655231685, 'P007984': 225864.79861982018, 'P007823': 37762.763007785674, 'P000378': 26973.20165415525, 'P007393': 63626.843669034686, 'P007249': 7658.58437056397, 'P007173': 4733.17390915434, 'P007982': 350945.6412224947, 'P000181': 1197.123850511946, 'P007132': 10201.576925849848, 'P000352': 347.1499940119698, 'P007320': 5661.872140397182, 'P007286': 6615.881038673242, 'P007115': 16834.82058033765, 'P007321': 23091.64503680664, 'P000241': 927845.9340936077, 'P007150': 11157.54457350198, 'P007151': 8381.864921425735, 'P007397': 6840.864838058793, 'P000160': 298712.000572538, 'P000348': 4167.481151909693, 'P000020': 131646.60851577643, 'P007255': 19442.727295910096, 'P007333': 5370.557560100105, 'P000029': 29911.69458199452, 'P007325': 11412.699415025969, 'P007381': 24053.500177387952, 'P000170': 39906.17415442069, 'P007215': 31743.86016463543, 'P007145': 2147.343487069605, 'P007225': 9012.254995910484, 'P000040': 9746.726988934626, 'P007277': 3394.13068804387, 'P000298': 11402.80393689631, 'P007122': 62999.102764108124, 'P007368': 5455.242704039394, 'P000394': 197947.0193344123, 'P000395': 712323.4423995252, 'P000381': 126319.39239515924, 'P007251': 2126.1818732751767, 'P007243': 29339.690166435972, 'P007146': 9986.820034512943, 'P007338': 13081.392009213121, 'P000334': 6775.1224710842835, 'P007328': 9222.025418483787, 'P007244': 47749.85777148496, 'P007133': 19371.96696416277, 'P007152': 339459.3714800903, 'P007227': 56240.98170969602, 'P000052': 41322.44690674538, 'P007177': 344.94269186171925, 'P007354': 25657.923986768772, 'P000148': 58054.17535633563, 'P007402': 83992.51910354572, 'P007395': 7715.928462912695, 'P007347': 12568.667912214643, 'P000015': 11871.322822330285, 'P007193': 8418.555583851412, 'P000187': 126676.67947694231, 'P007239': 27506.142704378777, 'P007226': 27895.52674049846, 'P000347': 142151.21373263598, 'P007259': 3263.828077682725, 'P007135': 2149.293311434757, 'P007378': 24917.023531804778, 'P000256': 72195.07671084843, 'P007287': 3683.039022993708, 'P007387': 43377.48004472547, 'P007376': 12625.585534704524, 'P007305': 9251.099722871952, 'P000126': 2041.2941005800362, 'P007200': 9144.688408475555, 'P007300': 54461.19903977759, 'P007184': 57530.07789243781, 'P007143': 44805.554917431975, 'P000123': 312418.1004602979, 'P007120': 24509.051188619953, 'P007168': 114106.9969911264, 'P007199': 50493.372452341464, 'P000301': 37798.12662494958, 'P007408': 7289.815010887314, 'P007319': 22205.865473751895, 'P007986': 184904.21641575865, 'P007315': 26488.853809211127, 'P007166': 5350.855580303355, 'P000374': 92202.3342616379, 'P007116': 9392.764087475336, 'P000075': 275588.4390172429, 'P007295': 8139.881183722845, 'P007352': 10658.446767225294, 'P000236': 83640.80795791362, 'P000192': 6253.056293032329, 'P007121': 51594.77066714796, 'P007369': 61016.11005228847, 'P000344': 8742.542922201252, 'P007343': 6611.433294663154, 'P000058': 19487.541807525482, 'P007144': 10461.19790556798, 'P006193': 41767.88935419805, 'P002851': 21882.968241587736, 'P007624': 1055.7073138168098, 'P000168': 42060.32155726499, 'P007164': 2568.3852966739846, 'P007175': 38353.831845747154, 'P000306': 186220.57690711334, 'P007216': 7837.259047381359, 'P007322': 29179.199249971065, 'P000209': 2837.905254982738, 'P007236': 4058.9102389631157, 'P007126': 4658.058664179699, 'P007252': 1891.675227273521, 'P000277': 143986.68408889294, 'P007171': 1698.5900254422072, 'P007189': 4857.73287485728, 'P007298': 53483.03768539481, 'P007360': 17823.256913722038, 'P007308': 9621.963520614026, 'P007180': 267710.4244981918, 'P000360': 21706.33665786672, 'P007394': 5920.393469345346, 'P000342': 183888.16083292555, 'P007181': 56663.0418627172, 'P000231': 290301.51270454953, 'P007336': 12902.889230853838, 'P007283': 42968.74679234934, 'P000365': 100001.39795380848, 'P005500': 14392.756787473 ...

# %%
#On vérifie qu'on respecte le budget et sa répartion
def verify_phase_costs(phases):
    
    total_cost = sum(i.cost for phase in phases.values() for i in phase)
    phase_costs = {}

    print("\nVérification des coûts par phase :")
    for idx, infra_list in phases.items():
        phase_sum = sum(i.cost for i in infra_list)
        phase_costs[idx] = phase_sum
        pct = (phase_sum / total_cost) * 100 if total_cost > 0 else 0
        print(f"Phase {idx} : {phase_sum:.2f} € | {pct:.1f} % du total")

    print("Coût total toutes phases : {total_cost:.2f} €")
    return phase_costs

# %%
verify_phase_costs(phases_result)
# Out:
# Vérification des coûts par phase :
# Phase 1 : 1248237.91 € | 38.9 % du total
# Phase 2 : 592480.94 € | 18.5 % du total
# Phase 3 : 602219.30 € | 18.8 % du total
# Phase 4 : 765097.16 € | 23.8 % du total
# Coût total toutes phases : 3208035.31 €
# {1: 1248237.9123755174,
#  2: 592480.9411705484,
#  3: 602219.3031754037,
#  4: 765097.1551690063}

# %%
#On génere un fichier csv pour visualiser les différentes phases de reconstruction sur qgis
def export_phases_to_csv_from_data(data, phases, output_file="infra_phases.csv"):

    rows = []

    # Ajouter l'hôpital en phase 0
    df_hopital = data[data["type_batiment"].str.lower() == "hôpital"]
    df_hopital = df_hopital[df_hopital["infra_type"].str.lower() == "a_remplacer"]

    for _, row in df_hopital.iterrows():
        rows.append({
            "infra_id": row["infra_id"],
            "phase_reconstruction": 0,
            "duree_totale": row["duree_totale"],
            "cout_total": row["cout_total"]
        })

    # Ajouter les autres phases
    for phase_idx, infra_list in phases.items():
        for infra in infra_list:
            rows.append({
                "infra_id": infra.infra_id,
                "phase_reconstruction": phase_idx,
                "duree_totale": infra.time,
                "cout_total": infra.cost
            })
    
    df_export = pd.DataFrame(rows)
    df_export.to_csv(output_file, index=False)
    print(f"CSV exporté : {output_file}")

# %%
export_phases_to_csv_from_data(data,phases_result)
# Out:
# CSV exporté : infra_phases.csv
